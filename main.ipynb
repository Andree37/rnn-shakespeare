# %% [markdown]
# https://gilberttanner.com/blog/generating-text-using-a-recurrent-neuralnetwork

# %%
# Creating our dictionary
with open('shakespeare.txt', 'r') as file:
    text = file.read().lower()
print('text length', len(text))

chars = sorted(list(set(text)))  # getting all unique chars
print('total chars: ', len(chars))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# text length 425879
# total chars:  39

# %% [markdown]
# To get valuable data,which we can use to train our model we will split  our  data up into subsequences with a length of 40 characters. Then we will transform our data to an boolean array.

# %%
import numpy as np

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# Although creating a RNN sounds complex, the implementation is pretty easy using Keras. We will create a simple RNN with the following structure:
#
# LSTM Layer: will learn the sequence
# Dense(Fully connected) Layer: one output neuron for each unique char
# Softmax Activation: Transforms outputs to probability values
# We will use the RMSprop optimizer and the Categorical Crossentropy loss function.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# Helper Functions
#
# In order to see the improvements our model makes whilst training we will create two helper functions. These two functions are from the official LSTM text generation example from the Keras Team.
#
# The first helper function will sample an index from the output(probability array). It has a parameter called temperature which defines the freedom the function has when creating text. The second will generate text with four different temperatures at the end of each epoch so we can see how our model does.

# %%
from tensorflow.python.keras.callbacks import LambdaCallback
import sys
import random


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %% [markdown]
# We will also define two other callback functions. The first is called ModelCheckpoint. It will save our model each epoch the loss decreases.

# %%
from keras.callbacks import ModelCheckpoint

filepath = "weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss',
                             verbose=1, save_best_only=True,
                             mode='min')

# %% [markdown]
# The other callback will reduce the learning rate each time our learning plateaus.

# %%
from keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=1, min_lr=0.001)

callbacks = [print_callback, checkpoint, reduce_lr]

# %% [markdown]
# Training a model and generating new text
#
# For training we need to select an batch_size and the number of epochs we want to train. For the batch_size I choose 128 which is just an arbitrary number. I trained the model for only 5 epochs so I didn’t need to wait for so long but if you want you can train it for a lot more.

# %%
# train epoch
model.fit(x, y, batch_size=128, epochs=100, callbacks=callbacks)
# Out:
# Epoch 1/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 2.0750
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "nd, who wooes
# even now the frozen bosom "
# nd, who wooes
# even now the frozen bosom him and the south the shall the string
# the shall the sead the shall in the shall the shall sir,
# and the lid the shall the planter the sead of the streats to the shall the seed the sead the shall the for the say and the sead the sin the shall sould and the for the sine the say the shall the father the proming of the sard the say,
# and the sould hamlet shall the sould and the sin the sark the seall t
# ----- diversity: 0.5
# ----- Generating with seed: "nd, who wooes
# even now the frozen bosom "
# nd, who wooes
# even now the frozen bosom cost the fares and the bading of the first,
# the sead and the sword, no should be and brutus of all hes and will the shull youne,
# and the countrant them the know in than the spuck in it.
# marce let on my lifir and not thou are made my love there and sir,
# the sore me nor ear a butter spilie
# he makes and thou hamlet as he then the plack and the stratien, and caesar mand: stand and it the brate of the
# ----- diversity: 1.0
# ----- Generating with seed: "nd, who wooes
# even now the frozen bosom "
# nd, who wooes
# even now the frozen bosom him talle you?
# enter lord, and thou to shall ound and mortanter, verembind thet.
# you tir shall our avilistisgest sanudar,
# and arrict:
# entire grold all the nursel hen terver hamlet't chesell cinis behent.
# king allut, thein atiin ward, if alle's,
# than nour nold nit ushoudilk grow: sual finey kill,
# romeo
# and it villen mint.
# bat spivile thar endur makes w: i gay sade;
# the youne be not will. with his b
# ----- diversity: 1.2
# ----- Generating with seed: "nd, who wooes
# even now the frozen bosom "
# nd, who wooes
# even now the frozen bosom sulk his will evertluse for ofts you lord? me
# bhith our h oud hear woth romens.
# come, cinst
# booknints offeser
# a'd cliprightiin, to rathe wis it he mint, -
# all:
# excuctus
# a'l apar hack if itinevod cesthome :
# benacko?
# then you, with vounm !
# caesar call mala!
# due
# hawe atth,
# dhan, cail'd opmforif hamlfggenscuil: welf drigh
# cupuret
# if at he will tod chascud,
# well's mi'lls? hee-
# well.
# laby foch on ferto'
#
# Epoch 00001: loss improved from inf to 2.07484, saving model to weights.hdf5
# 1109/1109 [==============================] - 110s 99ms/step - loss: 2.0748
# Epoch 2/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.6967
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ason comes
# wherein our saviour's birth i"
# ason comes
# wherein our saviour's birth in the seath.
# cassius
# and the speak of the some the sun their father
# what is the streat of the streation of the
# say, the straint and the shall be the strick;
# and the streat the sain the sear the should be the swear,
# and the see the see the speak of the sage
# and the pater the street the shall me that is the streats,
# and the should be with and prive of the strain,
# and the more the see the shall his m
# ----- diversity: 0.5
# ----- Generating with seed: "ason comes
# wherein our saviour's birth i"
# ason comes
# wherein our saviour's birth is not the sape
# cassius the mater for the surperre,
# and that is the dation of man's well:
# and the stand, and to the sagaint of spear;
# and the port brutus is that hands, when a king
# how shall show slaughted of the our should in the seet
# and parthiss of life, and like the sired be made thee but the grings,
# and metter liest thee means that will that on the
# will o'll which man the sorling streats,
# and
# ----- diversity: 1.0
# ----- Generating with seed: "ason comes
# wherein our saviour's birth i"
# ason comes
# wherein our saviour's birth is, and brow hdoked
# i be sduma:
# for this. the heous mochetys of in nounty
# a my pesple sfor the go food, craiis, if bounisscold.
# trief
# theris to be in hou heaven, give, and sunts?
# rosmnce, hel kseat:
# mad premoothys morothy his seally,
# farowers, that sonbulaty, now spulf it, there bess; and, where will.
# hamlet
# shile, that that let ilingade, cassius. when be good and this. have,
# by the father would ca
# ----- diversity: 1.2
# ----- Generating with seed: "ason comes
# wherein our saviour's birth i"
# ason comes
# wherein our saviour's birth imlaving mall-genot,
# betilet corlight and saymblire dispeaped'd bid's;
# and hall you rey wile, bustlusatem of lagrt:
# am; och as theey
# ay thee can how hear,--
# king claudius
# eye, and eting or bosich panii ficond;
# 'tsecvt ageer. wum day, die, me, alpedchiage
# i will girch's letbent my salkion:
# o know sorning with it' frakes of himb;
# but now i hause fid of sppeekitid
# that king's kit oikers, yet meet, let
#
# Epoch 00002: loss improved from 2.07484 to 1.69664, saving model to weights.hdf5
# 1109/1109 [==============================] - 101s 91ms/step - loss: 1.6966
# Epoch 3/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.5911
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ich carries them through and
# through the"
# ich carries them through and
# through the word, and the see the word in the see the capulets,
# and this heath the would this this to the morning this the word,
# and this bed the greet the seen the see the county,
# and this with the word it with his to the see the fit thee,
# and this street the word in the pere the seen the seen they,
# and this best the for this the see the searth,
# and this best the word it shall she this this the word of my l
# ----- diversity: 0.5
# ----- Generating with seed: "ich carries them through and
# through the"
# ich carries them through and
# through these hear with from the age the liet!
# i dead of make the likes the this day,
# and set the seen he word.
# mercutio
# mark him as the will hose i am the sunse
# it armance me tell some thy montagues,
# if the flatiss this fighted and sure end:
# and thy fliend parties of this which them.
# casca
# i will dead me that the his brien the dadital the beat behow.
# romeo
# it a shouts the firecterion to shout the
# carriss th
# ----- diversity: 1.0
# ----- Generating with seed: "ich carries them through and
# through the"
# ich carries them through and
# through the genor; is thy titch off her pert,
# me, por of thei?
# hure the fortuse you stoy.
# why, forsay
# thit and be't by saiker morn theisennce to-night.
# canna us dies
#
# king one
# and . comet
# it his clowns
# away! i not this nabloth head,
# i do most of but i am his word.
# all fruenter not fold, hoir end's juit.
# caesar, which manishor that made cailders,
# imord, you, and lefted this blind!
# o with bromed not to fathers
# ----- diversity: 1.2
# ----- Generating with seed: "ich carries them through and
# through the"
# ich carries them through and
# through the bodous of ynold's, carnous.
# and roved dead upcy,,' thy trumy-go tyball not fects the,
# steads rumh, eyes! yea, futchou himlge, with me,
# and no most we folknolidtion footys--roration!
# i'll thing be, once; folh, this in crown.
# dame. whereone by trymed followible our other
# it not  block with faw not: friends? myself:
# yes: a ve abinm: how at pooriatilyt sf deart:
# you monish well, caesarsss!
# 'divod thi
#
# Epoch 00003: loss improved from 1.69664 to 1.59119, saving model to weights.hdf5
# 1109/1109 [==============================] - 98s 88ms/step - loss: 1.5912
# Epoch 4/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.5315
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " horatio.
# horatio
# what art thou that usu"
#  horatio.
# horatio
# what art thou that usus the sendiest him thee besson and the soldiers,
# and what the sone the best the sendies, here,
# that she should in the seem the confenter,
# that i will not should and the prince and and the body,
# and the see the strenged and the see the country,
# and the shole the see the find it stand of the should of sould the see.
# horatio
# that i should in the since his man the hand
# and the seem the sone the sendie
# ----- diversity: 0.5
# ----- Generating with seed: " horatio.
# horatio
# what art thou that usu"
#  horatio.
# horatio
# what art thou that usure, in the unserves of the sole.
# brutus
# sir, i will a grief the sight of men
# that i will shall dasters heaven.
# hamlet
# what i love and and readged and these with this death:
# i those the poor than stones of i do crown of opers
# heaven. and the piegly, thou art sould the morning fall;
# he the prick of the paint that i will a the rose;
# and when these stath the since the body.
# the romeo, but stony.
# romeo
# ----- diversity: 1.0
# ----- Generating with seed: " horatio.
# horatio
# what art thou that usu"
#  horatio.
# horatio
# what art thou that usuded which als' camelles
# murderled in ocrown, to sly ho!
# brutus
#
# brutus she
# cassius? i have spuld their of me,
# let with manun redowave, what he comes with everwars?
# hamlet
# thy shile, and and their taken thyselun,
# whend i will not country, loved she plack, fell.
# this we in no semembe, give these word.
# good sir, full i as but she satkent.
# hamlet
# 'tis this soned a thee you, lady changes
# thy cloow. it
# ----- diversity: 1.2
# ----- Generating with seed: " horatio.
# horatio
# what art thou that usu"
#  horatio.
# horatio
# what art thou that usuid
# with set; it.
# ophelia
# not voporths of hearn
# night of grief the ground proants tond, :
# trie sincliesf? an backed and :
# stinps stringing.
# laertes
# a. your chmare, what e?tdoniage,sule visorn to scence;
# enchy hand how are posion brisherledhincance:
# rustly had
# : an ach most the guing for drudst let,
# what you but stats i'll vile woudursach antony-vive and had,
# any patient should, and, prostrons norst
#
# Epoch 00004: loss improved from 1.59119 to 1.53176, saving model to weights.hdf5
# 1109/1109 [==============================] - 92s 83ms/step - loss: 1.5318
# Epoch 5/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4911
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ll the field.
# nurse
# o lamentable day!
# la"
# ll the field.
# nurse
# o lamentable day!
# laertes
# some the senst of the send,
# and not the death of marry, and the portian
# with his bean to the send the portian's hand
# the pear the poor best the portion and caesar
# what is a street the portian's and thing
# when the porties soul, i think in the street.
# cassius
# is the seem and the street the death, i will,
# should be the streng the seem the world the serve
# what is not see the county with me and t
# ----- diversity: 0.5
# ----- Generating with seed: "ll the field.
# nurse
# o lamentable day!
# la"
# ll the field.
# nurse
# o lamentable day!
# lady capulet sleep this body.
# lucius
# lady capulet, and a prace is ding to the breathe
# by this cassius, to the near hath and man
# the cursed and break in the streat of this saw
# the poor to the second and my his county.
# good good good did he will, a find you with
# this bear me and here you with his a speak.
# cassius
# i will he seem't him defies die.
# capulet
# here thy the season of mine the poor and the cap
# ----- diversity: 1.0
# ----- Generating with seed: "ll the field.
# nurse
# o lamentable day!
# la"
# ll the field.
# nurse
# o lamentable day!
# laurtis
# the play.
# drumno
# juliet
# good madness in it brasts,
# who nothing who'sed in fairs, with thy this.
# juliet
# heles to wood is well with targe break to you ruse
# drawnve for this audient gage of minetatish brutus?
# you speak we, a see troup-is unbiriog may,
# whene i say, thou ald whal i lears in the
# atteness'd oin o man, may on!
# light, go, let's not a witch? hoxus, to me
# when you wapk,, shame i; if a
# ----- diversity: 1.2
# ----- Generating with seed: "ll the field.
# nurse
# o lamentable day!
# la"
# ll the field.
# nurse
# o lamentable day!
# lady, noble, that, kepping your perking
# revenge-sound, what you you day, ruprogn
# o'er welser-ones, sir; let's have wa?
# nerdairightss,
# make a peescepence wit to cause majenin this
# come, noblah with our hath no
# seal alkcolive king.
# what's flll shall nects's tree ca;saray,
# my lord.
# romeo
# men your discrricofuld beeve, re sope bridg stoeply.
# partion, more brutus, nay, shall be sinterco,
# and, sound look
# t
#
# Epoch 00005: loss improved from 1.53176 to 1.49112, saving model to weights.hdf5
# 1109/1109 [==============================] - 92s 83ms/step - loss: 1.4911
# Epoch 6/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.4617
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "me:
# look to't, think on't, i do not use "
# me:
# look to't, think on't, i do not use the tager'd souls;
# and the sporse the noble father be the word.
# hamlet
# hamlet his agery of my lord him a sun,
# and the spirit to my say the speet to the word.
# hamlet
# why, that i am the speet and see the true,
# and the word and the world a contage of the consow.
# hamlet
#
# casca
# so see the speet the world the morning of the countenter and the streets,
# and father and the world and so the man a thing
# and
# ----- diversity: 0.5
# ----- Generating with seed: "me:
# look to't, think on't, i do not use "
# me:
# look to't, think on't, i do not use the fantaly with
# least so fitest the world a thought of the beat,
# what this than the cousin to show bear a morning forthh the grage;
# the poor show and morning and the lad me fortanted.
# casca
# why, the concere him father forth the hold.
# exeunt
#
# nurse
# i'll coursthen kisses to the face.
# romeo
# i reshmad and freend in sweet to the man
# the reason of fortant he would leavery of for and the them
# puts up th
# ----- diversity: 1.0
# ----- Generating with seed: "me:
# look to't, think on't, i do not use "
# me:
# look to't, think on't, i do not use are fan the torthe:
# you pil hold cropbours of your morn with tidi
# encolann
#
# lady capulet
# antony
# adother high i player from his taher day
# farewell him one intermporioy and errongrina's sdie:
# vanroratce away it; good. hamlet
# antoty
# 'tis the drivorsm as i am true, being serve.
# romeo
# camber
# yesselve that romeo, so polings the fellowing coung of leceral
# and faulty asides as your find thou oncely night
#
# ----- diversity: 1.2
# ----- Generating with seed: "me:
# look to't, think on't, i do not use "
# me:
# look to't, think on't, i do not use not centrred
# at cordaligger: nobmet to juligute!
# rosemus
# pjudius he but out on this o'er
# where by ere it note you you-greel that wont, kis ha
# further answer scansonce?
# servant
# ashel, horradd you neverir;
# for hunt offence his doatin s'd. are mo!gor' mat
# thou; he will my gensthis: neys and fortunes,
# prihes he in praper to set lobe!
# as swear o' thy day forchooon!
# gertrude
# some husband awage this bone
#
# Epoch 00006: loss improved from 1.49112 to 1.46175, saving model to weights.hdf5
# 1109/1109 [==============================] - 93s 84ms/step - loss: 1.4618
# Epoch 7/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4393
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " antony.
# all
# the will, the will! we will"
#  antony.
# all
# the will, the will! we will shall she show the world,
# the speen the streets shall show the world
# the world and the more the streets the word.
# hamlet
# what will since the world be the streets,
# that will should be so fare them that with his souls,
# the speen to the winds and the streets and should be so soleming that shall stand
# the world in the world in she that the world,
# and bring them the world the more strange
# i will dead
# ----- diversity: 0.5
# ----- Generating with seed: " antony.
# all
# the will, the will! we will"
#  antony.
# all
# the will, the will! we will teach you, sir,
# that my senature to the them of this father with the players
# to come to heart brutus, i have them show
# the sweet to stand and whom but should in that some that with this with the most
# the purnomor of when this is and for thee,
# as the sperosen to speak to them in the wine.
# brutus
# what sampied but i will tembers and bring them,
# that caesar of love it was much a mantinats the mind.
# h
# ----- diversity: 1.0
# ----- Generating with seed: " antony.
# all
# the will, the will! we will"
#  antony.
# all
# the will, the will! we will is this solemy carhon.
# cassius
# lo!king do devan the tassor, then thr me.
# exaunt senat
# and than 'tonquan, my bright by two this,
# some nothingly cornsarred in the common,
# be's not by her
# would second for at  talk and when i enger
# elies
#
#
# do, what burnous of bentluch by: sickbeenct
# look, think i print, i soothsage oan.
# servanth pinntrom, and which you singsth?
# nay, hom the imingassainceg stranges
# 'o
# ----- diversity: 1.2
# ----- Generating with seed: " antony.
# all
# the will, the will! we will"
#  antony.
# all
# the will, the will! we will't that she arty
# so murdel, the : saw'd you'glll foly this:
# i brightaneing my father's revepeen prevouge
# in soldier, the noble whocs earth of his will.
# hoblin, as a minds them, us in,
# octabe you to nobran, i fear him tain you.
# o, our same grived,--
# tybalt
#
# thy mete you, too.
# experntbors os it no morts us should fsohels:
# rosencrantz hengesed me, answer
# not -to womb.
# mercutio
# phatch, ly set; the pai
#
# Epoch 00007: loss improved from 1.46175 to 1.43931, saving model to weights.hdf5
# 1109/1109 [==============================] - 92s 83ms/step - loss: 1.4393
# Epoch 8/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.4204
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "nine till twelve
# is three long hours, ye"
# nine till twelve
# is three long hours, yet i shall i will shall stand.
# hamlet
# i will sirve the strength of the strength of the matter.
# hamlet
# i will show the strength and the strength and the world me and the greating thee.
# hamlet
# what the world the world me and the strength and strength of the friend,
# and the strength the strength and the friends the world me and the compessed.
# mercutio
# what the world in the provound thee that i will sa
# ----- diversity: 0.5
# ----- Generating with seed: "nine till twelve
# is three long hours, ye"
# nine till twelve
# is three long hours, yet well the breared and
# a strength and lay thee here then, be his away.
# hamlet
# and where is not be with the strength the wend.
# hamlet
# no more day, and if the fore shows the bants
# the strengs so have the most from the world makes
# that no find show the find i am the will.
# exit horatio
#
# the first you show the dreams of the must.
# exit firew speet vital
#
# fare is the sleep in the fair of steel his say.
# m
# ----- diversity: 1.0
# ----- Generating with seed: "nine till twelve
# is three long hours, ye"
# nine till twelve
# is three long hours, yet and decait!. ! been tam.
# but geltrapo, is , fareweng therein rath:
# dry pleant and a over a lave, hit delkint,
# or it be so hadner's cortingst provemin is ,
# and, and for anyout: for the achea thy eit
# then that such all slount of his their his heart;
# marry, that swell'd fair courty to shall men,
# sit; how in we be player, as i' book not.
# horatio
# i show you thec!
# hamlet cannot and nongation, that nan
# ----- diversity: 1.2
# ----- Generating with seed: "nine till twelve
# is three long hours, ye"
# nine till twelve
# is three long hours, ye besile, fellows pick a-say,
# sreence of chaces so much antony's be hor.
# hamlet
# .
# king claudius
# a murder'ds with su: and notz of llaw.
# benvolio
# to then, to enduar much forey too;
# parague, mercutio, hay a callage thee fellows up
# yeel to tipt herred bood how whttised the pigga!
# sme is confession time, wis a a's hibrest.
# romeo
# and to crown
# romeous own, we usidier than a very cassis be with one-ban?
# nu
#
# Epoch 00008: loss improved from 1.43931 to 1.42050, saving model to weights.hdf5
# 1109/1109 [==============================] - 92s 83ms/step - loss: 1.4205
# Epoch 9/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4055
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "t fortune, death and danger dare,
# even f"
# t fortune, death and danger dare,
# even for the more the more the face,
# and what is a strenged the word of the word.
# hamlet
# what is a strence and the more the word of the will.
# hamlet
# what shall still the word and the word and the more,
# and the word in the word and the capelet
# the speech for the course, and the word for the capitol;
# i will not the strence and the word of the play
# cassius, what not the part the word of the word.
# hamlet
# wh
# ----- diversity: 0.5
# ----- Generating with seed: "t fortune, death and danger dare,
# even f"
# t fortune, death and danger dare,
# even from his wear your capulet, what the great by mess,
# and the will he did be read the ware to red
# what not the word and courties sword, shall offend me
# they shall show your leave a sime the more.
# this shall she will we move to do bestrift,
# and greakers not purself of the fithers with it: with his seal,
# and the more the play and men of face,
# that in the noble lord hamlet, wherefore be good frow it,
# th
# ----- diversity: 1.0
# ----- Generating with seed: "t fortune, death and danger dare,
# even f"
# t fortune, death and danger dare,
# even friend, if the eyes romeo, are bear
# bears it love you and noe it merrend.
# brutus
# for that, his birt, or speak contravaly fine,
# but well that be a swears of mortal there's what.
# why, why moby spard my thankingation in face
# chrosst call too will wavery,
# and they go madey from a guests, proins there
# it is there is no your let to felf, orang of his liwe.
# or ifs their ind me: jubrand we man awave by nab
# ----- diversity: 1.2
# ----- Generating with seed: "t fortune, death and danger dare,
# even f"
# t fortune, death and danger dare,
# even frighte. could give coad, gentle with
# these wakess.
# cassius
# gent to parhel,
# do the own age it, marcumandur loak!
# hamlet we will's by by his dogry,--
# enter, good rosencrantz
# good night a flaw thy such 'twold proper by conse,
# to
# mendulps be the
# this: all the stand misecwan-caragve.
# but sooks, in thy montague,-nurst. and drown a littered.
#
# enter stay.
# da'tlem, shrisippinate young-'-feetly, see, and n
#
# Epoch 00009: loss improved from 1.42050 to 1.40548, saving model to weights.hdf5
# 1109/1109 [==============================] - 94s 84ms/step - loss: 1.4055
# Epoch 10/100
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.3902
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: " long? nay then, let the devil wear blac"
#  long? nay then, let the devil wear black.
# hamlet
# how now, shall be the world in the head,
# and the world the seen thee by me and begany.
# hamlet
# why, they shall i am the bears.
# hamlet
# how dost a strait the world of this man,
# and the world and the searth thee by the comper;
# and the world in the peace thee to the cases,
# and where is the matter is the capitol:
# but shall i am some name to seek thee but the wind.
# hamlet
# why, they shall shall
# ----- diversity: 0.5
# ----- Generating with seed: " long? nay then, let the devil wear blac"
#  long? nay then, let the devil wear black,
# if this as is this?
# romeo
# what, what a heart, he shall seek you?
# cascis
# once, and show him a dead,
# and seem thou ind and letter and where benvolio,
# that i may called you the creather,
# and do you to this contrad of me,
# who speak not be fortune thy leave; that with this toose break in the window,
# and show thee have were the point:
# do your same with the death.
# hamlet
# i might be mad hear,
# the head
# ----- diversity: 1.0
# ----- Generating with seed: " long? nay then, let the devil wear blac"
#  long? nay then, let the devil wear black'd
# in the head, put we shr?inianst the late.
# bernardo
# our, he gra?
# servant
#
# second let us wardy, oldic by your shade;
# that artayer, your footiclers, and he second forse,
# shall i kill be's hands of here:
# on ,re him to
# king.
# enter here yar the who clome not foot
# unerve king?
# parchs
# o, i devipentanble saint:
# and even i know for she that natting:
# mercutio, and whesint that by more; i,
# sore she should
# ----- diversity: 1.2
# ----- Generating with seed: " long? nay then, let the devil wear blac"
#  long? nay then, let the devil wear black.
# brutus
# as come murder's neuse is friend ambeddies at i trants
# for a virtuivesadarrded begin at evervell:
# montague; thelvoling begare up forseln,
# and hear charge, what, and imisher? for she know
# may chisming with to this wish
# took your mis calpons, doth wouch much me:
# there widst me never of chat's,--wile,
# since name, o this sin'd'st him in
# loa; if the very clakin'd lods. dear bade
# iwar of eye,
#
# Epoch 00010: loss improved from 1.40548 to 1.39041, saving model to weights.hdf5
# 1109/1109 [==============================] - 94s 85ms/step - loss: 1.3904
# Epoch 11/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3795
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "ave positively said 'tis so,'
# when it pr"
# ave positively said 'tis so,'
# when it prod the player of the hands to the courteons
# to see the matter hold me and and makes with heaven,
# and that is the matter to see the hands,
# and the speed and make the poison, and the words,
# and the find this wind of the courtiers.
# brutus
# hat is the word the word to see the matter for my bond
# and the speed and hear the soldier of the strick,
# that i will not to hear at the word to see the streets.
# and
# ----- diversity: 0.5
# ----- Generating with seed: "ave positively said 'tis so,'
# when it pr"
# ave positively said 'tis so,'
# when it prod her consent and out of the court,
# to seven is my father of grow good best it.
# hamlet
# not is speak and when the poison of him.
# the watch, do the sun the world that is well,
# tear her slain that the house to the true.
# romeo
# ay, that you would well itself and and atteng
# to set and matter 'batch. the word for your heaven,
# come, and the draws was the streth of my life.
# enter caesar
# hast at the shed t
# ----- diversity: 1.0
# ----- Generating with seed: "ave positively said 'tis so,'
# when it pr"
# ave positively said 'tis so,'
# when it preflint.
# hamlet
# o, good juliet good by peter by. you judgme
# estandly speech
# what out trouncomband at child!
# this usencescoon, if mere wellly lath behind.
# nurse
# not reafty guildenster toam shippers player
# came what is the bad hall strate, tempes
# ' find how day fagces pitcher death again?
# hamlet
# ow. why it wave,
# sir, now, musrne rase you not not.
# you know we wound yet he hath you didst.
# guildenstern
# ----- diversity: 1.2
# ----- Generating with seed: "ave positively said 'tis so,'
# when it pr"
# ave positively said 'tis so,'
# when it prant ills for, brahd ty, tow ca
# tal a master, say,
# theve vime-to bentae that what satom see,
# lord thieds 'te, bewell and fagesafomentofy break puilloti's litel'
# shall mouth shall imem. eyet but then, and twi's.
# we srak if an, onpit with thems'd?
# horatioic
# the ded a emtetue! rich
# entarder inme--if mock endards: rest,
# what mid,in't crand, but find if this closs. tow,
# to liers forgest me, afton mother
#
# Epoch 00011: loss improved from 1.39041 to 1.37952, saving model to weights.hdf5
# 1109/1109 [==============================] - 96s 87ms/step - loss: 1.3795
# Epoch 12/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3701
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "rday the bird of night did sit
# even at n"
# rday the bird of night did sit
# even at not the matter the word of the house,
# and the pation of the beauty of and and and the man,
# and the word in the seem to the word of the word.
# hamlet
# what is the word for the house, and the came to the searn,
# and the seem the word the capitol;
# the word of the word with a man of the stricks,
# and the word of the will be the seem, when
# the strength and seem the seembous to the cause
# the word of the word
# ----- diversity: 0.5
# ----- Generating with seed: "rday the bird of night did sit
# even at n"
# rday the bird of night did sit
# even at nothing---
# hamlet
# i am that he should this hand,
# that it with this cause the stany,--
# since art me to god for my patience with the cause,
# is the will it as his another will the polonius the citizen,
# the graves of more witter spokes in his triels by will.
# she enger of his compant to the matter.
# lady capulet
# the pate the true, i death the grace he show,
# for the will, go and shows it is a will to the
# ----- diversity: 1.0
# ----- Generating with seed: "rday the bird of night did sit
# even at n"
# rday the bird of night did sit
# even at night to thy joblthance, ehting
# what a must in our sportesmanct; thou art
# a quest not of at antony, looks,
# i am county espricewaly rom and pare my contixio,
# in your air, so i spoke her house.
# first clown
# no sighsed pied him aris,
# senatlim me to day toppuacy, and what, with the own:
# laest
#
# hamlet
# why, by her from his my cause wounds the king?
# say hown harhinain,'d but have not hath sight,
# we mine o'
# ----- diversity: 1.2
# ----- Generating with seed: "rday the bird of night did sit
# even at n"
# rday the bird of night did sit
# even at nobe, in this hed
# dier it senefevering and shed, your same:
# spoapsy? came! some him, and would soegnore.
# mourth cillgo's he lief. appery here-feart;
# juliet.
# dages
# o'er well.
# lady capulet
# gatfhisalinaon in cannot me, rumbel, prwake
# bofive more above ervis path, forlichalf.
# oarludien
# he side. whose curds, want, bid me with sir.
# whenher
# whises, i was play too you iudwif.
# romho, like is forcuns, ssa; t
#
# Epoch 00012: loss improved from 1.37952 to 1.37006, saving model to weights.hdf5
# 1109/1109 [==============================] - 102s 92ms/step - loss: 1.3701
# Epoch 13/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3616
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "ark's a prison.
# rosencrantz
# then is the "
# ark's a prison.
# rosencrantz
# then is the world be so speen to the courteonion.
# the world the bloody the line to stand and the lines
# to the world streth the point to thee their and me,
# and the lain our live and the county but state,
# to the point in the lain on the more.
# cassius
# i will lay me to the lines,
# and the world in the county to the borth.
# o come and the world me to the borth,
# to so hall the points to the lines to so soul,
# to stand
# ----- diversity: 0.5
# ----- Generating with seed: "ark's a prison.
# rosencrantz
# then is the "
# ark's a prison.
# rosencrantz
# then is the prince, and what i will men shall it crapling the guilters:
# and bring thee morrows a misers' grief,
# and thou shall sendst in a full of its,
# and thou art men of conscime, and sirs
# to romeo's son the more openter that streets,
# and if my couniny bodish do put on this soul?
# think you will be so in his slocked live.
# hamlet
# why is the couniny in men and like sounds
# and dood on the fair of streeds,
# to th
# ----- diversity: 1.0
# ----- Generating with seed: "ark's a prison.
# rosencrantz
# then is the "
# ark's a prison.
# rosencrantz
# then is the world spor be surtiting amban their end
# upon your motten me here, i do pack.
# antony
#
# take istil his and thinks notrings pien,
# laikuge their sendded inalled with a deeld to
# metiers with his forgedn-vercod
# faith. but go along'ds!
# take it day, and she sleep, alls to faith.
# o, this seek might be here to it she think;
# he will young take it to-night day most spectlous.
# now, thou speak to sa. god talk he
# ----- diversity: 1.2
# ----- Generating with seed: "ark's a prison.
# rosencrantz
# then is the "
# ark's a prison.
# rosencrantz
# then is the rogning cheeks dooth expirlder.
# friar laurence
# xerynssay, pulo?
# this servant
# pase, by this sights young juliet:
# very leavep my dent wiing brother's fasentais
# that nunnous: some youthfit fall pacter'd,
# well suy, my alte-to hourss; but, look be some again:
# farewelld eleg on mess of that think upone;
# onour it a moner; love, if this hobation,
# come the altblied tow on this povery.
# o luse,ing, liest wee
#
# Epoch 00013: loss improved from 1.37006 to 1.36159, saving model to weights.hdf5
# 1109/1109 [==============================] - 102s 92ms/step - loss: 1.3616
# Epoch 14/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3527
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "not the very button.
# hamlet
# nor the sole"
# not the very button.
# hamlet
# nor the soles the streets of his best the death,
# and the prince and soul, and the play, the matter and the streets:
# how did the play to such a streets of the players's sweet:
# he shall so shall so hath seen to the course;
# and the more the streets of the seents the prince and the streets.
# hamlet
# why, there is no matter and the streets and the course;
# and i will do not should be the streets:
# the prince the court
# ----- diversity: 0.5
# ----- Generating with seed: "not the very button.
# hamlet
# nor the sole"
# not the very button.
# hamlet
# nor the soles the flower us in the course;
# and then she should be a conder'd prince,
# and man it desire the sword will love
# the more of the capelets not so haste of the circup;
# i shall be reason and too caesar, so sweet in stricks a come,
# that are the death and deving of the fire,
# a could we be the mother fastion of your many
# to soul the strength to the cords, i shall be heart.
# benvolio
# no, nor do you she shou
# ----- diversity: 1.0
# ----- Generating with seed: "not the very button.
# hamlet
# nor the sole"
# not the very button.
# hamlet
# nor the sole, with the tame at hich of a fit them.
# brutus
# where are cassius; i must 'tchion; helps this worbled:
# benvolio
# mestition no, i, the peaser'd lord.
# hamlet
# a fiend awakerow.
# myenfscen, a corrdon beach,
# and you go to ham' bondmiteys shricide,
# yet i should have same on the wicks your pinarce'st beg,
# ! wi' couns: you will, so he is they along
# uncrente fraite; please thy shall resuin:
# not the prince wope
# ----- diversity: 1.2
# ----- Generating with seed: "not the very button.
# hamlet
# nor the sole"
# not the very button.
# hamlet
# nor the solesate i'll fere, and for a father.
# brutus
# young full retions sleeping his times whose carrie;
# so disporterchly as terp, dothings too the play,
# took find us fate if caesar!
# friar launes, you i sive them them with worbed brutus!
# as no thou clows starn up a sincety bat this ?
# why, no lest unswouve fare thee or concknly oh a pretly.
# hild de
# i xell scipince, i'
# : limberious, fire-da lree; med; where lor
#
# Epoch 00014: loss improved from 1.36159 to 1.35268, saving model to weights.hdf5
# 1109/1109 [==============================] - 105s 95ms/step - loss: 1.3527
# Epoch 15/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3465
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " the everlasting flint:
# a lover may best"
#  the everlasting flint:
# a lover may best the things and the streets
# and the streets to see thee be the supper
# the serving to the speech to do you be so.
# hamlet
# i will stretch of the words, and the heaven
# when the street to so scander be more that i will
# have all the servant and shot the play to stand
# the play to sin well, and the play to be so the streets,
# and the strength the bears the play it the prince of men
# it is the play to shall
# ----- diversity: 0.5
# ----- Generating with seed: " the everlasting flint:
# a lover may best"
#  the everlasting flint:
# a lover may best thou to my dood that we with
# the bory the great do be son of the seal,
# let their proper be in my born!
# exit there's makent with me hear me not be not good hear
# when not for the water with a very montague,
# calls a man may villain, and he so sight,
# and make the comples and the prick of the will.
# lord polonius
# i will she stretch to shall shall other.
# exit
#
# alasus, that is the will;
# and the continuse
# ----- diversity: 1.0
# ----- Generating with seed: " the everlasting flint:
# a lover may best"
#  the everlasting flint:
# a lover may best that off tybaliut it.
# juliet
# o, if it hit i fearfull: here all resolvd
# me some undial shand, and the ceasm, what ut, o, likelie-be
# hamlet, wilt laugh forthful misoll.
# capulet
# 'tis that the solderly.
# third citizen
# an i. ick-in me denmise romeo like
# is copale my noble fearful ma not bone,
# no
# murderelwshing hamlet.
# exit orce same body polonius
# o, it were so in word to cold 'tis enter
#
#
#
# enter home,
# ----- diversity: 1.2
# ----- Generating with seed: " the everlasting flint:
# a lover may best"
#  the everlasting flint:
# a lover may best this hunsle a life'st;
# : pleasing apothgutus tlaster:
# no woocue!
# let them all might of my like thee from
# into thouse. ope, to the scripbwx!
# a
# bria
# thee for ly judgnt,
# that's i for fellogon what it she:
# you giel muschel, who smell be guildensteral,
# carrition.
# good laemus
#
# juliet
# is ty, i lie, simplossel you beggean shale.
# let theme, hath skull seem sa!p'djofy.
# nurse
# what is other etherwsh me accle
#
# Epoch 00015: loss improved from 1.35268 to 1.34645, saving model to weights.hdf5
# 1109/1109 [==============================] - 105s 94ms/step - loss: 1.3465
# Epoch 16/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3394
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "villager
# than to repute himself a son of"
# villager
# than to repute himself a son of the word of many.
# horatio
# it shall so much the capitol;
# which so that make the put on the prince of my sweet bring thee brutus,
# and the purpose the word of him, and the capitol;
# i will not so much the matter'd cannot me the pray,
# and the worning the thing the speech is the winds,
# and the put on the put on my says the put of
# the put on him a man the breath of the word,
# and the purpose the point: a
# ----- diversity: 0.5
# ----- Generating with seed: "villager
# than to repute himself a son of"
# villager
# than to repute himself a son of the capes,
# and i speak to the winds of this fair maning of the most friend!
# and a capulet in the searments of me!
# come the pathes, and thine and deads, which, well, i would will not a a confessing and master's death,
# for thou art the heart for the capitol;
# and i will come to this players of his love
# to the scining me that reciond the word,
# and now their fire the some the present brutus?
# brutus
# i
# ----- diversity: 1.0
# ----- Generating with seed: "villager
# than to repute himself a son of"
# villager
# than to repute himself a son of rome; my and thine
# will not say from she not not romest, men,
# or away, cleasued alsecmyslosse it.
#
# lord hot come, cinnat of laves of the philisous,
# with a fasiony, he to repois; and in't was becing.
# cannot, performencnty fine himleting thates
# well-gherr, cassius, is place our hagiein?
# osric
# old me in this hath caesar waketmon,
# letber
# many most your it. sir, a memp it reas; the ender
# till tall the
# ----- diversity: 1.2
# ----- Generating with seed: "villager
# than to repute himself a son of"
# villager
# than to repute himself a son of a morrow till thou
# ghcerast
# lady lock, reace in hims sphandar, put their reven then, brudy.
# brutus
# sure, hiall too moon outmakent and mys.
# brutus
# ramber, we love chapies bains ereore
# nor will not, rekn eferemable atalor frose
# to it go, movely not?
# lucius
# every hearth the for 'speef two be not:
# i will tardoth humour, believe meet'ds: do old his own.
# and it prock to chidencery, tike nesip we-bs. he
#
# Epoch 00016: loss improved from 1.34645 to 1.33939, saving model to weights.hdf5
# 1109/1109 [==============================] - 104s 94ms/step - loss: 1.3394
# Epoch 17/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3316
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "ree and twenty years.
# hamlet
# whose was i"
# ree and twenty years.
# hamlet
# whose was in the word of the station,
# and i will be so secourt to see the strength so so seen
# come the staper the profess of the mortain,
# that i am to so see the strength to see,
# that i am the strength to see the courts;
# and the strength to see the mortun,
# to see the matter of my force of the streets,
# and the statul me to the prince of my courts.
# hamlet
# i am the strength of the strength the word of the stree
# ----- diversity: 0.5
# ----- Generating with seed: "ree and twenty years.
# hamlet
# whose was i"
# ree and twenty years.
# hamlet
# whose was in mantuars, that the name to come.
# repent speak and men of me? blame thee too me,
# the word of the prince to stay it: it is all.
# laertes
# the attents and this the second in the stape:
# and men shall she is a friar laurence;
# the prince to call the strength to be so long,
# if the sweet we more and slaves with thee gone.
# mercutio and citizen
# all the pato and so shall have well in the bassing wit and more
# ----- diversity: 1.0
# ----- Generating with seed: "ree and twenty years.
# hamlet
# whose was i"
# ree and twenty years.
# hamlet
# whose was i more invenunonstornes with her fly on lefrer!
# lord polonius
# i from him chimlent bloid.
# do, thou wilt early will wind of by me,
# these blandman,'s no ladmence; and, good o, my mitition;
# he's over then they aside. and gring,
# and mark you have some-fees
# ere we to that the sear to fain, megd withint,
# that so proved in, i fight we of this;
# caesar! lest the nablen; i have gratious:
# i know'll time to be
# ----- diversity: 1.2
# ----- Generating with seed: "ree and twenty years.
# hamlet
# whose was i"
# ree and twenty years.
# hamlet
# whose was ink'd; twent. braver clreaud ours, my griet,
# all late find an thourstly, letbery say
# we till ever, romeo's speet, sour:'--
# liburnts of ladmerd kink hank i' se it:
# in find if nothing thy aga.
# ghtas frimb did montast book defecness
# to bear on my caisas blood!
# player
# you, times gruaids manrows ilp in, for exoughtings
# to heop kissilition with a head srone,
# i'll cairin to samn offence a tor-pot-lusty.
# b
#
# Epoch 00017: loss improved from 1.33939 to 1.33160, saving model to weights.hdf5
# 1109/1109 [==============================] - 105s 94ms/step - loss: 1.3316
# Epoch 18/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3277
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "elves
# another: you jig, you amble, and y"
# elves
# another: you jig, you amble, and you are the poside,
# and the world is the matter to the polonius.
# hamlet
# o much and the world men, the put thee saw;
# and then the world it is the world in the strengt
# and the world in the seem to the polonius.
# hamlet
# the thing the world in the world in the strengt
# and the man the world that is a greed
# the world in the world proved the world.
# casca
# and then the world it is the strengt
# and the world i
# ----- diversity: 0.5
# ----- Generating with seed: "elves
# another: you jig, you amble, and y"
# elves
# another: you jig, you amble, and you did see,
# to the world be the world in the entlear it the please,
# and seeps so thinkines to the lairing did his father
# to the hands to light to the table;
# and go to the world and you with the closet
# to the postadist and a man;
# for i may not there and at your soul conse--
# as now of the body and best of the cale wither
# with my breath, as i must be the world live.
# my lord, is the enemy best the sou
# ----- diversity: 1.0
# ----- Generating with seed: "elves
# another: you jig, you amble, and y"
# elves
# another: you jig, you amble, and you may nollt
# of your distremin man ig bernegn.
# benvolio
# nay, every his furbele, were not repent,
# must dribufrous ourselv, with my lips, dreams cassius.
# ophelia
# i romeo laugh with too latess and his fawittion!
# op our your with antony, might, hed sundain,
# orowirk-lore and thouscands, lef have, blindst lep cuttagust at shade to stoos,
# to remait of themablears do out our luffly men,
# that else endurder
# ----- diversity: 1.2
# ----- Generating with seed: "elves
# another: you jig, you amble, and y"
# elves
# another: you jig, you amble, and your a gell the thiu kins!
# come to thy swearous womling
# were patient musicm divhip were to stielf tion;
# first stird! airdelment, confessions so so, prese
# with his petfone? look, thy leave the roem
# anoth. goo hold life you be show, time.
# so. a sulace ssounest is cunnive,
# masstanius. met'l thdose an, thus, casca is to the clons near yes,
# see, detted thy grief thwself they maver
# valumin arded.
# farebel
#
# Epoch 00018: loss improved from 1.33160 to 1.32772, saving model to weights.hdf5
# 1109/1109 [==============================] - 102s 92ms/step - loss: 1.3277
# Epoch 19/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3214
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "thy brains no more about it, for your du"
# thy brains no more about it, for your durse.
# brutus
# what is the fair to the streets of the blood
# to the seas the friends, and the streets.
# sir, hamlet and the world the guilty of this best of streets.
# and then the point, for the play to the friends,
# and the streets of the friends of the mother.
# brutus
# i will not so much man the speed the streets.
# hamlet
# what marral of the world in the prince of thee.
# hamlet
# i will not so the streets of
# ----- diversity: 0.5
# ----- Generating with seed: "thy brains no more about it, for your du"
# thy brains no more about it, for your dust:
# then the shade the worse had crown with thee.
# there are the from my speed; i have thing the seas.
# mercutio
# what might the gunss, and the greeped the noble
# but not here from the matter there as to thee.
# mercutio
# o'er in the world his sweet of marral is shout
# and abour shondy to my caesar; thou hadd
# unto the gree--
# great gentle brutus, and boding blood,
# and the soul mindery farewelllly doubt
# lea
# ----- diversity: 1.0
# ----- Generating with seed: "thy brains no more about it, for your du"
# thy brains no more about it, for your duar treath.
# nurse
# no ewah, put onds pooten and on, hand,
# say cousins a tou her further.
# hamlet
# what loft retomon and prid torsein,
# : i have into the acher consorch of so.
# -cere is the outs of min't it was which,
# and what dignest sleepor tears for ma?
# told gal times and heed i purion.
# what of pity better two 'tiis? abriak along
# have constake so slou! :
# brutus fith jeture
# a slers,'g, fortun's loves,
# ----- diversity: 1.2
# ----- Generating with seed: "thy brains no more about it, for your du"
# thy brains no more about it, for your durnial.
# friando
# how wi! i sul, i would i kiniest them rojesm:
# stir farchuses, it; octavius:pin s' off?
# aboesting and incouracty,
# mucht their inest trwald! seemy stumt his sease:
# you worcommk geatery in this heddiem; with the soal,
# whenger not my hid? him, time for incep  his friented.
# prism, do gien's, that, comecture anothers
# in bscark'd, and i budy farewed the head.
# cassius
# if broker my feesens h
#
# Epoch 00019: loss improved from 1.32772 to 1.32137, saving model to weights.hdf5
# 1109/1109 [==============================] - 112s 101ms/step - loss: 1.3214
# Epoch 20/100
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3166
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "hildren of an idle brain,
# begot of nothi"
# hildren of an idle brain,
# begot of nothing and the world be so forth,
# when the sense--why the word of the world
# the word of the senate-time the word of his soul,
# when the world the world the world is the castle.
# romeo
# i will set thee to the world is the world
# and the street the word of the mother in the castle.
# hamlet
# why, then the world is the world the words,
# and the word of the heavens and the reast to caesar,
# when they say you to th
# ----- diversity: 0.5
# ----- Generating with seed: "hildren of an idle brain,
# begot of nothi"
# hildren of an idle brain,
# begot of nothing? i have is the world is the word:
# when the play's curent a most in this bestrent that their faith.
# from this but his bound of my exemntry and cassius.
# what day is the rest and it in the weats
# to caesar's sender of love that is the bestrew and thing that the streets,
# when he should be men of for the thing in say's bed
# our part of a sense-prac's cimber; when they say,
# that he envisit to make the
# ----- diversity: 1.0
# ----- Generating with seed: "hildren of an idle brain,
# begot of nothi"
# hildren of an idle brain,
# begot of nothire; ifly is betol'd, as expenty:
# caesar, foughts is what marriebly anday these name?
# good good god, and calls men for my pluckpres,
# with youneveom. is you might then all.
# franciscasmy'
# are my house, not.
# mustly and death, what bove withouts
# to do, then, we lay undrore rose us of him ill
# given a heaven.
# mercutio
# cockiness, caesar.
# prince
# o will the play, awhile as bit thee opposite.
# hamlet
#
# hamlet
#
# ----- diversity: 1.2
# ----- Generating with seed: "hildren of an idle brain,
# begot of nothi"
# hildren of an idle brain,
# begot of nothing; that with hearcting, well.
# stilport
# hi: good with alkon agies and me onburce.
# good foel, ca, meant to his legp evend?
# follow ever so nop good god father,
# rown ald, capulet thyself, her.
# what here of my be afarce as butge be flubr'd,
# what wlive, my such anwids, you was traed
# for let i dops of this !
# cassius
# ha? within, tybalt' satisfy kinsjort death.
# struct imanto man themscarn mednot:
# but let
#
# ...
# horatio
# my lord, i warrant, if it dothings,
# is did a spake the window, marcuse think'st thee stands:
# he is and romeo, with this best ourselvese,
# that i am the world more romeo be withoutw
# as will his negul to be sudden from him a courten'd for the streets,
# and that is enters.
# ostan
# marcellus cassius
# as i have seen the provode him sorrow of my
# exile in exercy and of many fi
# ----- diversity: 1.0
# ----- Generating with seed: "d my duty, as i hold my soul,
# both to my"
# d my duty, as i hold my soul,
# both to my ease to ration's nighe; for what was
# now calls no word be porselit, if he respent.
# brutus
# what is the pation: therefore doth their light,
# if this guildent need as now his limbs a tain,
# and he would proved things came?
# hamlet
# so pritue, i ware tyours benvolio
# break of palm in the proforted are times,
# in his a greathing and power earlly pass
# have some in grates full drown her pro!
# piter
# sour
# the go
# ----- diversity: 1.2
# ----- Generating with seed: "d my duty, as i hold my soul,
# both to my"
# d my duty, as i hold my soul,
# both to my dead after will with mief;y
# or tweppets womlir, what will not come,
# two , my fate of nunt haste nef are her face:
# art thou be.
# every with you alone, by. i were yet thusbel,
# where you piece love that you are an officut.
# first clown
# why thene you much envyoff and for our sight:
# the corring deper so life, our death sin
# wathe? nurse
# no, i like so:-dectition, fellow upon thy same,
# and these upon the n
#
# Epoch 00094: loss improved from 0.79817 to 0.79637, saving model to weights.hdf5
# 1109/1109 [==============================] - 120s 108ms/step - loss: 0.7964
# Epoch 95/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7948
# ----- Generating text after Epoch: 94
# ----- diversity: 0.2
# ----- Generating with seed: "tizen
# we'll bring him to his house
# with "
# tizen
# we'll bring him to his house
# with a supply to speak to the point:'ibe!
# hamlet
# why, that i say, and for the matter, and see the profatcus daugh some'd that i will
# opposites with the strenge of the world
# that i will do not there are the matter;
# and they say the street of the mornien,
# and that i have man; if they say stand:
# for thou have man it is a flower or him.
# lock, horatio! what says my lord.
# hamlet
# why, she shoulljes to see the
# ----- diversity: 0.5
# ----- Generating with seed: "tizen
# we'll bring him to his house
# with "
# tizen
# we'll bring him to his house
# with his time to the king against his fast.
# there art thou have seen us, if you show,
# in this will i will do never better.
# this itself his upience and the heavens,
# and in the face of many masters; there is no bears in your grief,
# and friendur, the world it is.
# brutus
# not stondly than the scaper
#
# lucius
# he weeding to the father statul bet her state,
# that i will we could not speak to stand again.
# rosencr
# ----- diversity: 1.0
# ----- Generating with seed: "tizen
# we'll bring him to his house
# with "
# tizen
# we'll bring him to his house
# with caesar's heart of the most darkors this feett him therefore,
# being could pery, you given and cassius;
# and for some dism'd, and let me sine their unsole;
# for let the friend him gone to morning's ove;
# --natt let to the carrionful light, then?
# romesx upon a crass, now, or the modns and thing unwill;
# and you shows love their reeding to thee.
# what thou shalt keep consal gend. opposing
# the skull was mos
# ----- diversity: 1.2
# ----- Generating with seed: "tizen
# we'll bring him to his house
# with "
# tizen
# we'll bring him to his house
# with some mas. juliet must all a censtruss.
# philippy for thoughtse your husbands his own,
# which the wind'st lip gear come for that the portels eath,
# renvy in the matter: but brutus best thy means to his stand
# with thy loud it too never you goodseold!
# i lay go to you remient from that must stard,
# my soundst thou, let me sun.
# rosencrantz and citizen
# nex men fertal moote by rosencrantz, !
# farcart shaupows
#
# Epoch 00095: loss improved from 0.79637 to 0.79478, saving model to weights.hdf5
# 1109/1109 [==============================] - 126s 114ms/step - loss: 0.7948
# Epoch 96/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7952
# ----- Generating text after Epoch: 95
# ----- diversity: 0.2
# ----- Generating with seed: "caesar
# stand you directly in antonius' w"
# caesar
# stand you directly in antonius' will.
# love me with a choose the pointce: and at his side
# be within the seal and drinctiscepan of there
# the death singits and such a sensed men,
# with a shotter of himself; and what to your livery,
# do you not there as a case thee from him.
# nor setched thou art thou his sourch,
# and for the matter, the serviagely.
# brutus
# he weep youn capulet's house.
# hamlet
# why, that i will we have sere blood in the mo
# ----- diversity: 0.5
# ----- Generating with seed: "caesar
# stand you directly in antonius' w"
# caesar
# stand you directly in antonius' will.
# love me and noth durse, brick thee friends,
# or many moon me, makes to caesar's dead.
# hamlet
# how i am the point:'ir hands lives are whole
# what is the bloody.
#
# enter good lord, i do beset of the heavenly.
# hamlet
# how now, this bestreath, where you are fail me:
# sirdus, go to the polonius with the world.
# brutus
# i will with thy point. seek him a feep and his surredd
# some romeo be some noble recksal
# ----- diversity: 1.0
# ----- Generating with seed: "caesar
# stand you directly in antonius' w"
# caesar
# stand you directly in antonius' will!
# souls
# ourther discroum lost,
# the quiet comes to himself, for the agerif?
# first clown
# i am, do you be octive hath sable.
# romeo
# i must wome clouds should do more husice?
# be to thyself, here do not another harms of jase.
# juliet
# 'that put you, are the pay to bed,
# and this sick, if the matter's runion
# tible with you, then, reward a weaked from his laughter,
# that we have sett a
# common cassius, stan
# ----- diversity: 1.2
# ----- Generating with seed: "caesar
# stand you directly in antonius' w"
# caesar
# stand you directly in antonius' will!
# li, is noth all hastery.
# ophelia
# o, come was massalibly bravion not a age,
# and furt is these ngroet: i'll keep mousee; which, i shall fover!
# romeo
# i gaspisece, go akiege,
# of romen on cairius in sutcrevent you.
# ;ry vile a swear: repaid fortunr'd, and your were you and long,
# ass; doth such nother her! doth at the very hase,
# as were your aff retrewhfwhether that though yest,
# that for the priment
#
# Epoch 00096: loss did not improve from 0.79478
# 1109/1109 [==============================] - 123s 111ms/step - loss: 0.7952
# Epoch 97/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7926
# ----- Generating text after Epoch: 96
# ----- diversity: 0.2
# ----- Generating with seed: " me trudge:
# and since that time it is el"
#  me trudge:
# and since that time it is els--will livers
# i will with a suppless of my fathers,
# who stiet thee from his purche there brave with me,
# the world with his death and for the mornip;
# he is not as well saink'd what i should be his her face,
# that i will we mullerpeatt thee from thee
# with this time to the poison to see the streets,
# and there is taynll may capit: gherch their own'd
# the pointce; is be thus hear the mindilence.
# nurse
# n
# ----- diversity: 0.5
# ----- Generating with seed: " me trudge:
# and since that time it is el"
#  me trudge:
# and since that time it is ellments of this dearth,
# and adbeling at allow of my mindst.
# cassius
# that not sett of the point: therefore should me,
# ant the quality by his menvess. i will lie
# wrans't, i will not come to the capitol.
# horatio
# i will tell us well. a lias more them so much claud.
# varrion me that boods and point; and it will.
# lord polonius
# i will not speak in the streets of him.
# nor set this saw them as brutus.
# capule
# ----- diversity: 1.0
# ----- Generating with seed: " me trudge:
# and since that time it is el"
#  me trudge:
# and since that time it is ellwan to comming at a wings?
# exit
#
# hamlet
# i have, thus the headsely and pestirnd,--
# now is villain.
# exeunt servant
# lovary, sir, stands his roud in beftercelone.
# benvolio
# that you have so set them so.
# hamlea
# peacess do you furnia wablers, and bring thee rhus,
# reguen goes instrumt the daughter, sir; the bade
# and love some best with his shook him all the wide,
# and provise would disks thou reedick asau
# ----- diversity: 1.2
# ----- Generating with seed: " me trudge:
# and since that time it is el"
#  me trudge:
# and since that time it is ell me, go grouds:
# juliet'e, lost spaber
# moke what nombers are other last us.
# have i mad, benn guirl'd, pardot apo?
# romeo
# seep me'd will through at the purcher;
# becarast warture; your fierment, i, all death
# wasives us creature hath shop it intory guild,--
# ob, a amoth unto these blest so.
# marcelun
# come, now must indifflesatens; fly in death
#
# enter guildenstern
#
# antony, wherefore, i love be her undert
#
# Epoch 00097: loss improved from 0.79478 to 0.79258, saving model to weights.hdf5
# 1109/1109 [==============================] - 121s 109ms/step - loss: 0.7926
# Epoch 98/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7905
# ----- Generating text after Epoch: 97
# ----- diversity: 0.2
# ----- Generating with seed: "lcome, gentlemen! come, musicians, play."
# lcome, gentlemen! come, musicians, play.
# enter all gentay, well!
# speak! what is the screper, and the world
# whose fortune's seen and strengnt of man
# the cause in the mornix. is is the point:
# and thou art thou hast sensigh of the poison
# come, that i have seen the matter, with thee to the father.
# brutus
# ay, that with a window, be are the matter,
# that i am the poison'd labe.
# romeo
# what says if the sin's blood of this.
# marcellus
# what, i will
# ----- diversity: 0.5
# ----- Generating with seed: "lcome, gentlemen! come, musicians, play."
# lcome, gentlemen! come, musicians, play.
# enter nurse
# ay, look, he is out,
# and here the mornim are to see the compul so.
# horatio, that i am between chpose and reash,
# and for the watch, i do not known it night,
# 'tis thy dear the leap the strenge of the leave.
# caesar
# he shall be your seal'd capile:
# 'tis will: if it is not for the mornix.
# and this is thy lessing dink and dismom.
# casca
# i do not let most bosom. and these sirs,
# and from read a
# ----- diversity: 1.0
# ----- Generating with seed: "lcome, gentlemen! come, musicians, play."
# lcome, gentlemen! come, musicians, play.
# enter all viou
# hamlet, what as the reason to be his help,
# the rest and els-honoved, accord
# capcustoor. what say at his well as phethell,
# he cast theself many prince how of the tasian.
# ?
# lord po-c! thy heart.
# romeo
# my lord, all this fellowshy to-night.
# king onin hast briefly.
# antony
# well, what as you have we good most too up me.
# they in friar laurence, but see dow me forwam toward
# what master's no
# ----- diversity: 1.2
# ----- Generating with seed: "lcome, gentlemen! come, musicians, play."
# lcome, gentlemen! come, musicians, play.
# sweo: what is't more vain, at endure him make
# as same, la?-you know's two ews to him:
# 'tis well are that you are free! light, should father
# what is this it in the air. but nercoal her, gone, for suiden,
# ypuan; do not vairhu, gi.
# enter mpeat, let up as chose upon his own.
# cool, hear staved by thee with remore.
# cassius
# laxies
# succ what crewablrskgne!
# marry, lady lordy? lady, sweet spokest.
# friar la
#
# Epoch 00098: loss improved from 0.79258 to 0.79054, saving model to weights.hdf5
# 1109/1109 [==============================] - 112s 101ms/step - loss: 0.7905
# Epoch 99/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7888
# ----- Generating text after Epoch: 98
# ----- diversity: 0.2
# ----- Generating with seed: "n here,
# it is an honest ghost, that let "
# n here,
# it is an honest ghost, that let me sir.
# enter lady! lord my lord, what made than i will.
# lord polonius
# it is a shot well: good my lord, i will.
# lord polonius
# i will come, and there is taynll on the streets,
# and that i will we have sere in a capiton:
# i will not speak to such a disposer'ds;
# which he long of my sword, you have way,
# that i will we have sett your mindsten's most scarfffity
# much that i will we have more those him that
# ----- diversity: 0.5
# ----- Generating with seed: "n here,
# it is an honest ghost, that let "
# n here,
# it is an honest ghost, that let me sur?
# horatio
# i will have made them spirit of this.
# mousth! o, but a suppless: then that you shall lives
# it speak neced men of his death and cause
# or my mend me?
# cassius
# then sightly shall give him a true hand
# at not the world in his last a man,
# that sucklipubbeg of this hand and more married
# than hath sent a word with a mason, sweet good:
# when the sigure, and guildenstern, sir, i have seen to-n
# ----- diversity: 1.0
# ----- Generating with seed: "n here,
# it is an honest ghost, that let "
# n here,
# it is an honest ghost, that let us good have alongo
# o, degrant all age of cassiusly from his face.
# servant
# as love, but we will, as the rests the feath,
# that their man of this can dogured his point.
# if thou had cheerate sight in men
# carries and by night, love their certrour with eyes,
# to stort him thy livery of fire man of pairam
# from his cannoted and discoy, i am gonger
# that is it caesar; and mercutio believe to thee with
# the s
# ----- diversity: 1.2
# ----- Generating with seed: "n here,
# it is an honest ghost, that let "
# n here,
# it is an honest ghost, that let shouth. juliet alooge!
# your cause and clappot, being she with you;
# havio, lights of the dewelicksthion,
# with birtiest doot of her offend in it.
# brutus
# i our, and red welce gow and not not yeath
# he dary murder of rome.
# exeunt
#
# scene ver at limets, whet i chall?
# hamlet
# octavius
# than my drunbs most villains to thing day.
# romeo
# through o, that's the waran? and, as you ! a us,
# and imported enduect her
#
# Epoch 00099: loss improved from 0.79054 to 0.78881, saving model to weights.hdf5
# 1109/1109 [==============================] - 118s 107ms/step - loss: 0.7888
# Epoch 100/100
# 1109/1109 [==============================] - ETA: 0s - loss: 0.7891
# ----- Generating text after Epoch: 99
# ----- diversity: 0.2
# ----- Generating with seed: "ho!
# brutus
# good countrymen, let me depar"
# ho!
# brutus
# good countrymen, let me depart:
# sceneting in the strenge of the world,
# and that i am the matter by the point:
# and thou art men of men can do your soul how
# so faty of the son, and the point!'s--masters.
# antony
# none, when they do noble rest the gods of this;
# and the rest shall it proper confeins the reason,
# that i am to the play's enemy, caesar;
# thou wilt see the world; and then the poised
# the death and by the mornix: is if the
# ----- diversity: 0.5
# ----- Generating with seed: "ho!
# brutus
# good countrymen, let me depar"
# ho!
# brutus
# good countrymen, let me depart.
# rosencrantz
# we are are to doth round, or if i will do
# whtre a stree of meming of my shouts.
# cassius
# i will be too salt, gright good friar laurence
# o, brutus, my lord, i shall fortuness.
# re-enter horatio, sir, this he dream:
# there is thy same cala?
# how who he shall speak and ravellow, and he was
# no more of caesar, sweet struct
# even the emble to the capitous. when the
# hath senterfofut his name's
# ----- diversity: 1.0
# ----- Generating with seed: "ho!
# brutus
# good countrymen, let me depar"
# ho!
# brutus
# good countrymen, let me depart.
# and stand word as friar cassius in the brave,
# her figuther. lost yer hamlet tister.
# romeo
# i speak and madness.
# exeunt servant
# 'tis well.
# exeunt dalls
# the unfort
# is consently men,
# to eviry with his shond man himke trosout their actiop the right
# for i pray thee to thy benvolio
# paris; he is my such death. good daugh at bed a contrad,
# my name believ. quith slack. noybaly, parting
# the cause in the c
# ----- diversity: 1.2
# ----- Generating with seed: "ho!
# brutus
# good countrymen, let me depar"
# ho!
# brutus
# good countrymen, let me depart.
# !pounces do not sir, i desiren.
# romeo
# they do not soundly we att thee face,
# that upon the awabbring trash do
# wormiust antony. tent my chinain, she see.
# ;ry brutus misals side,'s, such
# will thy king me we presembment.
# prince
# i prace, like a fasion in are leaping
# trasow, till stayal and peter belp; thene these to itca:
# give his peter with a heart: be und for take
# dead, and by in caesar; but, as a
#
# Epoch 00100: loss did not improve from 0.78881
# 1109/1109 [==============================] - 119s 107ms/step - loss: 0.7891

# %% [markdown]
# To generate text ourselves we will create a function similar to the on_epoch_end function. It will take a random starting index, take out the next 40 chars from the text and then use them to make predictions. As a parameter we will pass it the length of the text we want to generate and the diversity of the generated text.

# %%
def generate_text(length, diversity):
    # Get random starting text
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    for i in range(length):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char
    return generated

# %% [markdown]
# Now we can create text by just calling the generate_text function:

# %%
# generate text
print(generate_text(250, 0.5))
# Out:
# r of what might fall, so to prevent
# the standed is at the earth her face of the streets;
# and she is, you and there is no more thans
# the roman be read, the world it did true.
# what, with heavens, my lord, i am to thee,
# to caesar's spiring with all the bloody,
# and for the winds, to live thee

# %% [markdown]
# Recurrent Neural Networks are a technique of working with sequential data,   because they can remember the last inputs via an internal memory. They achieve state of the art performance on pretty much every sequential problem and are used by most major companies. A RNN can be used to generate text in the style of a specific author.
#
# The steps of creating a text generation RNN are:
#
#     Creating or gathering a dataset
# Building the RNN model
# Creating new text by taking a random sentence as a starting point
# The details of this project can be found here. I’d encourage anyone to play around with the code and maybe change the dataset and preprocessing steps and see what happens.
#
# There are also a lot of things you can improve about the model to get better outputs. A few of them are:
#
#     Using a more sophisticated network structure (more LSTM-, Dense Layers)
# Training for more epochs
# Playing around with the batch_size
# If you liked this article consider subscribing on my Youtube Channel and following me on social media.
#
# If you have any question or critic I can be reached via Twitter or the comment section.
