# %% [markdown]
# https://gilberttanner.com/blog/generating-text-using-a-recurrent-neuralnetwork

# %%
# Creating our dictionary
with open('shakespeare.txt', 'r') as file:
    text = file.read().lower()
print('text length', len(text))

chars = sorted(list(set(text)))  # getting all unique chars
print('total chars: ', len(chars))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# text length 425879
# total chars:  39

# %% [markdown]
# To get valuable data,which we can use to train our model we will split  our  data up into subsequences with a length of 40 characters. Then we will transform our data to an boolean array.

# %%
import numpy as np

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# Although creating a RNN sounds complex, the implementation is pretty easy using Keras. We will create a simple RNN with the following structure:
#
# LSTM Layer: will learn the sequence
# Dense(Fully connected) Layer: one output neuron for each unique char
# Softmax Activation: Transforms outputs to probability values
# We will use the RMSprop optimizer and the Categorical Crossentropy loss function.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# Helper Functions
#
# In order to see the improvements our model makes whilst training we will create two helper functions. These two functions are from the official LSTM text generation example from the Keras Team.
#
# The first helper function will sample an index from the output(probability array). It has a parameter called temperature which defines the freedom the function has when creating text. The second will generate text with four different temperatures at the end of each epoch so we can see how our model does.

# %%
from tensorflow.python.keras.callbacks import LambdaCallback
import sys
import random


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %% [markdown]
# We will also define two other callback functions. The first is called ModelCheckpoint. It will save our model each epoch the loss decreases.

# %%
from keras.callbacks import ModelCheckpoint

filepath = "weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss',
                             verbose=1, save_best_only=True,
                             mode='min')

# %% [markdown]
# The other callback will reduce the learning rate each time our learning plateaus.

# %%
from keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=1, min_lr=0.001)

callbacks = [print_callback, checkpoint, reduce_lr]

# %% [markdown]
# Training a model and generating new text
#
# For training we need to select an batch_size and the number of epochs we want to train. For the batch_size I choose 128 which is just an arbitrary number. I trained the model for only 5 epochs so I didn’t need to wait for so long but if you want you can train it for a lot more.

# %%
# train epoch
model.fit(x, y, batch_size=128, epochs=20, callbacks=callbacks)
# Out:
# Epoch 1/20
# 1109/1109 [==============================] - ETA: 0s - loss: 2.1011
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "er and your honour.
# what is between you?"
# er and your honour.
# what is between you?
# lady
# cassius
# and so it is the the manter and he were the heart,
# and and the manter the his beant the his the heart,
# and the ment love in the manter the mest for the ment me so be were is the have a manterny and the all the manter in the manters the manter the manter in the with the manter and the heart of canst of the heart for the with the mant as so the ment is the manter and the manter the hat
# ----- diversity: 0.5
# ----- Generating with seed: "er and your honour.
# what is between you?"
# er and your honour.
# what is between you?
# let him hamlet
# hath not is the the manty dit, my lord, and the heart, of the prode the him the eneritions and is there let a marient gord, and i have with me not binot as the mant and the his above the bless of my lord, which the wears, i wasch, for the marry, and and and a the speen with your speak i dast for him her but shors most flee priged it of me is for as his given for the tarsy of gellon
# ----- diversity: 1.0
# ----- Generating with seed: "er and your honour.
# what is between you?"
# er and your honour.
# what is between you?
# dreat find faie, toinct dether pass. man it: thy i swenven; and juck leg to meril thbir heart, which intmer night no
# -roventy upon love me, he sear mochs.
# of bett norur,
# for agawe capoiony of bore's twaies no besout soce'd,
# moriatus;
# whatly
# cert moched'fut
# with what mantan every.
# enter, you. thos you'd itant fimlin.t.
# hamlet
# firsa
# a swold i
# horatie ?
# cuch, ars it ibrnat he wanded
# 'birponghts
#
# tod
# ----- diversity: 1.2
# ----- Generating with seed: "er and your honour.
# what is between you?"
# er and your honour.
# what is between you?
# besing vet
# enourh my bost menoy sen
# to heentoge thing thy most corrsery,
# rombo
# dowret's catch frittp.
# fwigin; and of mast ghonce;
# felicion for,
# goid he admarder gente; bur him,
# thewcats yiencej
# cy put; not the apurnep?
# fore and sucpith thy for oy -unthe wouldst ose wo-thin; the ? me gover to you a not.
# pxaap's
# up, er wheles look's to'sthil, sfo
# weth?
# dosd sho.
# -lutius
# how have fuesing oakness of
#
# Epoch 00001: loss improved from inf to 2.10105, saving model to weights.hdf5
# 1109/1109 [==============================] - 170s 153ms/step - loss: 2.1011
# Epoch 2/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.7127
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "then i shall see thee again?
# ghost
# ay, a"
# then i shall see thee again?
# ghost
# ay, and the best the will not the man a will.
# hamlet
# what should in the will part of him soul,
# and be a send the see a stand and the man the ander and the will the speak the wanders,
# and in the more a read of the man a send
# the count a will in the death of the more and the thee.
# laertes
# what was a see the ward a send the seeven
# the count the more a with the death a seet
# to him with the capulet and the
# ----- diversity: 0.5
# ----- Generating with seed: "then i shall see thee again?
# ghost
# ay, a"
# then i shall see thee again?
# ghost
# ay, and, and what that she will see.
# exeunt
#
# exit in stoothting your thou him with the mading
# and what we made the may seckne forthyes
# and an hamlet the earther the romeo
# that, we wear him a bagken should be menter the fation in the san he to him
# have with a griat of our do should be in this
# well in go have youth the matter and a shall of the count
# a prace; i'll well the ambing the reaping
# hour the rut
# ----- diversity: 1.0
# ----- Generating with seed: "then i shall see thee again?
# ghost
# ay, a"
# then i shall see thee again?
# ghost
# ay, and him on thicking, come to sike some,
# he both by aloverasts in to ackrices, knows,
# from what take dget aquiteing?
# fourth were elly is thy bilt up;
# what is was too, be are fiell mrdes come;
# marring i knorming as dath! did not mine,
# o, dashean shall was businer to witk
# sadder apregless a boke sweet; and, pursors,
# as ary fart bond to chaedion. begalich? brutus but did be wuck a
# my you, and my sword,
# ----- diversity: 1.2
# ----- Generating with seed: "then i shall see thee again?
# ghost
# ay, a"
# then i shall see thee again?
# ghost
# ay, and most lire he. guesmere peesait salk arove eart
# coly go moy so nigut and seck; we not,
# let; ir ate, on the windunor:
# lieh and the spoes.
# give rove your saw, hide; de. great say we incote lovess us,
# lotiles only boviceer fustyon'd,
# it hif offort hove to deat hangnr,
# ey, would nabkles: stiffs'm posmens. loves
# i ar, he clest rafonteved sam and bhoods.
# cleservah
#
# ugern
# be, which midangranl-'d!e
# it i
#
# Epoch 00002: loss improved from 2.10105 to 1.71272, saving model to weights.hdf5
# 1109/1109 [==============================] - 166s 150ms/step - loss: 1.7127
# Epoch 3/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.5987
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "o my love!
# drinks
#
# o true apothecary!
# th"
# o my love!
# drinks
#
# o true apothecary!
# there the head to the crown and the tongured
# to so the work to the was i will to hear,
# and so man and the can the such a man the toose
# that shall the word in the most the such a man,
# the was to come to should be the words thee,
# and the word is the man the the heavens the the his wead,
# and that i this the word be the the heavens
# the heaven to shall the most the part his bear the words,
# and the hand t
# ----- diversity: 0.5
# ----- Generating with seed: "o my love!
# drinks
#
# o true apothecary!
# th"
# o my love!
# drinks
#
# o true apothecary!
# there of the dark of it and ourselves.
# exeunt cassius
# i have such solver his dead to do sorress
# unened a put the tine live with his with a suffere
# it should grous as o his blood my lord,
# i will with his wook of the more the news
# to me of the toushented and let me man our head,
# and what should be her carse, and come come,
# and thy love against head be hear the hoars
# ap the such a bear to the last of m
# ----- diversity: 1.0
# ----- Generating with seed: "o my love!
# drinks
#
# o true apothecary!
# th"
# o my love!
# drinks
#
# o true apothecary!
# there have are may with lorg him; what elecuen,
# his bear with tosw ownosathtoll pelptous,
# and 'tis nightnather enrue!
# exeunt page celpes a king?
# caesar what shord, and, mark thew too come,
# here, of thy tibe thou within, head among
# mocrow, and inditce,','
# o have is. the crudden'dr through shot pleity:
# but upbree-much you from the whose lietia;
# which no pite my crounden it avonger the
# mote any secing
# ----- diversity: 1.2
# ----- Generating with seed: "o my love!
# drinks
#
# o true apothecary!
# th"
# o my love!
# drinks
#
# o true apothecary!
# the finst from sirquar, to a persooved well.
# with horse be eneme, cainot. doin. that sballery of
# may fot, aganms's con?
# so; they meop.
# pusinershedd, cupions you you, and i know,
# mad, hand eyelloarcia!
# cinnentuseed ato him would fortivoun thee, what not chell wasctaldents
# subment to-nifetl, i did gree gown goones
# his dunger us roesaon, fec-
# a-cingon when oldid and ofsere flose;
# the phised blood; a .g
#
# Epoch 00003: loss improved from 1.71272 to 1.59871, saving model to weights.hdf5
# 1109/1109 [==============================] - 179s 162ms/step - loss: 1.5987
# Epoch 4/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.5380
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "
# strange dream, that gives a dead man le"
#
# strange dream, that gives a dead man leave.
# cassius
# the capulet and such a more the course the capsion
# what is the the such a matter the shall the heavent.
# hamlet
# i would be the heaven servant the course,
# and the course the more the course to the coull the count
# sour his shall the could the matter's serves,
# and the hand in the course the course to stature.
# hamlet
# i do supper in the course to the more the hands,
# and the hand to the surc
# ----- diversity: 0.5
# ----- Generating with seed: "
# strange dream, that gives a dead man le"
#
# strange dream, that gives a dead man leaver
# to this too must not that i delling lider bout,
# bestow the ond it a rest the too, and it should i shall shall be the capsion
# count on the sees thou list that he did distrus,
# and good the capitol of my means is stand
# must the hand it world that is he is the hand,
# where in why thou shalt but a gone: i would be thou great as a seat.
# the atter come to the nature.
# larke
# cassius
# what thou musider t
# ----- diversity: 1.0
# ----- Generating with seed: "
# strange dream, that gives a dead man le"
#
# strange dream, that gives a dead man letter.
# hamlet
# alasn, and my lord impades, thou shall.
# first plut you sin?
# come, mussive, he no gregsed,
# as; aughed marrisats in the most sword.
# me, po, mouty., but, father swenkere!
# horatio
# serving, where i do nothnems; wording discrouss,
# trusy!
# ophella it on his bidat of herse
# you from, i would every. ir speat up speak watch
# so; mestyving in enfue he: whyle the oble.
# hast tess night book to spowt'
# ----- diversity: 1.2
# ----- Generating with seed: "
# strange dream, that gives a dead man le"
#
# strange dream, that gives a dead man less, but worsed's hus?
# ay, gpordn
# now dear wimpet,-lord pown!
# vory concanias.
# to
# meel within, a turcy'd florsing,
# our spawn! and remmeller: aingluces: yes it; indnewn cood gall.
# pary, shull thusy upleage long to elly.bigude
# enrose, nor
# king claudius
#
# for eyning comn, be sermst of her word my
# himselis: as ciom, e sened ellow natter,
# at, but pore you upon up rsones thou
# go fls me off.
# my youndel, woe
#
# Epoch 00004: loss improved from 1.59871 to 1.53803, saving model to weights.hdf5
# 1109/1109 [==============================] - 181s 163ms/step - loss: 1.5380
# Epoch 5/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4966
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "in vienna: gonzago is
# the duke's name; h"
# in vienna: gonzago is
# the duke's name; he the many to the prison,
# and the grieft the capines to the streath.
# cassius
# i come to the more the streath, and the streath.
# hamlet
# when i come to the streets to the streath.
# hamlet
# what a the are the streath and purpon to the streath.
# cassius
# what i will not the matter and the purpos
# to be so so from the prived the streath,
# and the many of the streat and the profor
# seem the prince of the streath
# ----- diversity: 0.5
# ----- Generating with seed: "in vienna: gonzago is
# the duke's name; h"
# in vienna: gonzago is
# the duke's name; how the strewn'd no more thee and the stranged him his
# seak to the conport of your stry men she hears
# 'tis entle are streath.
# hamlet
# not be this most many shall the places.
# hamlet
# what thou have me and the streath, sir.
# brutus
# but the man streath, where i shall the fireward,
# and thou art the conport the creath and ment some to
# the streets and the monts are the bony of meants.
# romeo
# what, you well y
# ----- diversity: 1.0
# ----- Generating with seed: "in vienna: gonzago is
# the duke's name; h"
# in vienna: gonzago is
# the duke's name; hathor?
# cassius
# i i cassius
# now the arlese well them.
# griger
# do will diied how, it musin; much as at ports.
# grivis
# i will beasine and shall in ond in. at prip will dother,
#
# the grife most wife and slright.
# brutus
# neblest meantul'd head, come do notice of he his mable;
# antony hip thou shalt i find any acty
# from my letter. thereforalia pointly you brutus salm purges;
# what of this find means evortion
# ----- diversity: 1.2
# ----- Generating with seed: "in vienna: gonzago is
# the duke's name; h"
# in vienna: gonzago is
# the duke's name; hnown and thanks, is mess ipe, brind you,
# rousonthy bond?
# hemselurstro: gy : for me. nayure me
# heagy: therearth , within'npoin. with seeycextul liems,
# cive thans idecd- him enter; 'tis a graey,
# that cull my shaltion, and that murder, herald,
# i'll conthe not: ifry, of you head; it wear:
# good sera allen collice thee are me-ho.
# sarlay i am down
# along the piming lone tybelves gonerity;
# but wagfmer all
#
# Epoch 00005: loss improved from 1.53803 to 1.49664, saving model to weights.hdf5
# 1109/1109 [==============================] - 177s 160ms/step - loss: 1.4966
# Epoch 6/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4667
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "hy, i am glad on't; this is well: stand "
# hy, i am glad on't; this is well: stand the streets
# and we will he stand the torcher the presentle
# the speesh to the morning the thing the tormation
# the matter and the world the naturt the streets
# and stand to the presentle and married not
# sent the might the read to the rather and the streets
# and the provion the daughter of the streets
# the prince is the morn the dead the conselle
# to the proper the speesh and married the streets
# and the
# ----- diversity: 0.5
# ----- Generating with seed: "hy, i am glad on't; this is well: stand "
# hy, i am glad on't; this is well: stand of it.
# romeo
# brutus sam and what though is desire with
# a spenot hold the world of the cuples in the streart
# to sir.
# cassius
# and if you not with him the matter, and
# the should and you the little gentleman,
# and friend to the father be thee well be
# the mornius smations the consired not the bosing
# so prosed a death, i will nothy doth mark
# the capitol the shame dratter.
# cassius
# the instoning sight it.
#
# ----- diversity: 1.0
# ----- Generating with seed: "hy, i am glad on't; this is well: stand "
# hy, i am glad on't; this is well: stand in carrabernh.
# antony
# whereting my standers, within you thisl death.
# casci
# along cly to a monter'd me?
# there! and thou artry of ground aft had efe; if there
# the fanterny; woold, so nothing' fellons.
# veronan, sir,
# both the bhow the lide? kind; upus, and second more
# eust with us look htos to dogls consage ati
# that are cassius; celpero! it shall be reinal me.
# o decius, and frear, is my egeves
# hit pla
# ----- diversity: 1.2
# ----- Generating with seed: "hy, i am glad on't; this is well: stand "
# hy, i am glad on't; this is well: stand evenims;
# fiet i warchy's not kerowlus; when but, where on the country mast'd
# repemong. inde laughell.
# romeo
# o, two leated, come to shall retzend?
# wame wheil times snick'd my fied, marchmant,
# i never for eif we lay theesaom;
# can be made man and -enterno but helling,
# and on the nest, the poitaits?
# .
# exeunt
#
# scene secong. see mact san delightsfor to see he
# 'twake awaust comed asy'ac you.
# phris not mu
#
# Epoch 00006: loss improved from 1.49664 to 1.46672, saving model to weights.hdf5
# 1109/1109 [==============================] - 179s 161ms/step - loss: 1.4667
# Epoch 7/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4438
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "nto dust; the dust is earth; of
# earth we"
# nto dust; the dust is earth; of
# earth were not so the body to the portia
# the slain of my sweet is the portia to such a sunce
# of the face of the face, and my lord,
# the bones of his confess of the face.
# cassius
# and the more the world in the choubless of the body.
# hamlet
# o, the world the point to the more the corfere.
# hamlet
# where i do not so should be so most speak down
# the sword of his bear the world of his friends,
# and the strewn the st
# ----- diversity: 0.5
# ----- Generating with seed: "nto dust; the dust is earth; of
# earth we"
# nto dust; the dust is earth; of
# earth were should be romeo in thee and outs.
# benvolio
# i am some his these for the heavens hath liness.
# now souls of my striege the nature and and
# her this be not the body to sunger my lord.
# hamlet
# let the stir you shall shall their speeders;
# the world, but this house of fire, should should be so,
# the good hamlet be a kent and hamlets of a close,
# and to creither the most miset of my lord.
# hamlet
# where i mu
# ----- diversity: 1.0
# ----- Generating with seed: "nto dust; the dust is earth; of
# earth we"
# nto dust; the dust is earth; of
# earth were bury gall to citioors: how molesealer
# it't, slucfen; which it take my denow you not,
# the things other and ophe: and, find can news!
# no, car yve thy huson of moce am hental canker'ded.
# laid our is re-enter as
# these basaniinate in our letterty corpablet.
# men
# this briat all citizen the ackions to rekniy elidsal's,
# but have of with done hear you lassion
# 'e which and you beas no, boin her is sweet;
#
# ----- diversity: 1.2
# ----- Generating with seed: "nto dust; the dust is earth; of
# earth we"
# nto dust; the dust is earth; of
# earth well.
# nightrains
#
# grient
# rown. cloudius;
# how it what must plagur. o heavtes' geflluge.
# exit mine or whit synet show
# the mortor, romening alls should mfet a conecy upon the greater;
# titinius is alme endeitisites.
# frienry nightly queenng vario, what sexence;
# yet ry, thi ghises the knot us were not welcerain!
# the elvious mockni-gime carch upon i lordfocler the light
# as thou.
# nurse
# shakedr ay, and thrus
#
# Epoch 00007: loss improved from 1.46672 to 1.44378, saving model to weights.hdf5
# 1109/1109 [==============================] - 188s 170ms/step - loss: 1.4438
# Epoch 8/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.4260
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "for i will speak to them.
# gentlemen, goo"
# for i will speak to them.
# gentlemen, good be so me the sees of the price are the word,
# they are the word the this will speak to thee
# the prince and purpose the price and the charge,
# and i do not so me and could and the seesar
# he will hear the could in the capulet the child;
# and the price and could the dead of the privores,
# and do not and this most could and the fair,
# and the will this body of the poison and courtes and friends,
# and the
# ----- diversity: 0.5
# ----- Generating with seed: "for i will speak to them.
# gentlemen, goo"
# for i will speak to them.
# gentlemen, good night, my lord of the portia,
# and this prick the body, with his besama's letter.
# hamlet
# i will do a fair on the dungeress most
# letter up to the see: and his most best with an evers.
# lord polonius
# i will be briefly she doo, stretting with
# a lift and the prittous like a fellow,
# and come and such a forch of the souls:
# now, good lord, they have father or messayer
# and the braded in the part of the co
# ----- diversity: 1.0
# ----- Generating with seed: "for i will speak to them.
# gentlemen, goo"
# for i will speak to them.
# gentlemen, goody, burish'd with me
# his papperns chiper me is no.
# hamlet
# hi this earth upon him; with the dimwelf thy leave,
# stello  or were mint fly up
# kind clown, to crough ild men hows.
# hamlet
# o my kind? but, o, he hears strengther from lady
# breaw his thrait, his wiflve forms, do i will,
# boys, well, then to love more him.
# brutus
# what yau art socuth. how i behove;
# ence heavtle, thick defuming onler wins soul,
#
# ----- diversity: 1.2
# ----- Generating with seed: "for i will speak to them.
# gentlemen, goo"
# for i will speak to them.
# gentlemen, good, pran you
# his tongue, sokentsiin.
#
# let entrin a ubkion; horatio, you must!
# but think him! let thou had on, afore,
# to wnot you; whuch not chipto vi'ght one thou?
# friar a
# proprit, clother; volume
# us so: so, casca and full him. laerteh!
# casca
# flly. 'tyin, pertums do nurfe, pa-goro, what,
# when hit mufe eyes our out, thou have do not used:
# when effaie you, sipwity: and, my life,
# when the gold thee w
#
# Epoch 00008: loss improved from 1.44378 to 1.42601, saving model to weights.hdf5
# 1109/1109 [==============================] - 133s 120ms/step - loss: 1.4260
# Epoch 9/20
# 1108/1109 [============================>.] - ETA: 0s - loss: 1.4083
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ore. i'll send to one in mantua,
# where t"
# ore. i'll send to one in mantua,
# where the word the soult to the courtes to the courte
# to thing the world to the world of the soul,
# what some so shall be so much have so thine
# for the soules the soult and the soul,
# so so much as thing to the mother shall not so shall not so comes.
# this some soul thee the world this soul,
# so much with me to the sensed to the portsorants
# and the world with the mother to the sound.
# brutus
# what shall so thi
# ----- diversity: 0.5
# ----- Generating with seed: "ore. i'll send to one in mantua,
# where t"
# ore. i'll send to one in mantua,
# where to the sun't with me and sound of my wart.
# brutus
# so my serven not of this one of the strentry
# in this words she from it not?
# farewell. but thou shalt mend his soul'd,
# where, this should believe the sence:
# and the world with this commons of your word,
# let them so frather and be discourse and holds
# it is the face, when the montagues of streets
# the soules my heat and commond shall tell your words
#
# th
# ----- diversity: 1.0
# ----- Generating with seed: "ore. i'll send to one in mantua,
# where t"
# ore. i'll send to one in mantua,
# where thing may we all his friend lived,
# for drived will be beators night-lains
# to you a notime! strations croble sedion
# and desperpures so very forged bloody,
# fourtered by's, say rocklat tell you was.
# gui. in this noble lordchideds sawonly abs.
# now; a--sirk, god hand king of, a quarred.
# vallant comem for that from his not; for
# which wore caesar your sin'rs in this chroat hies.
# justry brienst to soothly
# ----- diversity: 1.2
# ----- Generating with seed: "ore. i'll send to one in mantua,
# where t"
# ore. i'll send to one in mantua,
# where that is it e work sheat wercher,
# to modiy citizen known'd brick by firters
# a scharrled with casson se! ohring us sake stark, cascias
# and dose much indifule tonges clownl-d
# fo, to ony wordds.
# rosencrantz, if mark 'gon'd, my tebollelvis;
# indeen even came not o itpong, anothers,
# let to stir dety your death; but, caius thenct, their canot she ebs shalldaniun' slry antony;
# fault hope fall anane ry: but,
#
# Epoch 00009: loss improved from 1.42601 to 1.40823, saving model to weights.hdf5
# 1109/1109 [==============================] - 96s 86ms/step - loss: 1.4082
# Epoch 10/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3950
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "ow what we are, but know not
# what we may"
# ow what we are, but know not
# what we may not so means a shall the speak.
# hamlet
# i will speak to the county and the county
# part the world be so the friends are the course.
# there is not the price and the sound, and there
# the soul the sound and the world in the county
# a will the spirit and the soul the capito
# such a mistrantles the soul the prince and the world.
# brutus
# what a stop and the should be not so much,
# and there is not the speech
# ----- diversity: 0.5
# ----- Generating with seed: "ow what we are, but know not
# what we may"
# ow what we are, but know not
# what we may to the fill and blood him speak.
# dies, the same and his spaigor'd the king.
# laertes
# thou art in the county and there, then the prest dead.
# lord polonius
# i will speak the speek and countrypars the capito
# like and the cassius of the prince and underching and bear,
# that devil course me so fair a will the capito
# simf a ground and the tell it be so, the capito
# si caesar's capitious to his bads of the
# ----- diversity: 1.0
# ----- Generating with seed: "ow what we are, but know not
# what we may"
# ow what we are, but know not
# what we may and nighter
# why is the god, come.--rounting entred moreotings,
# and my matters in the crave itself.
# queen gertrude
# the grind and night sraik, and time; for
# satchocs, my laureness, by flour give his eatci!
# why should you she is not to caesar's fiars
# thou, if thou men yey with all the capitol.
# that must liefor. dind--enter ray'd
# whose point, and serve thee you: struck and out of me
# and stuck thee fl
# ----- diversity: 1.2
# ----- Generating with seed: "ow what we are, but know not
# what we may"
# ow what we are, but know not
# what we may vadislive to the god? aftis ted
# yets, that milius crewing; and thou defendagl;
# lom'der by him call opphirride! you shel.
# maourscela and theser behalt son, good pitiet.
# letil, hos she's mift vaint with their kiscmanless;
# thurise should want thist your coather performen,
# my chamber.
# king claudius
# foot hold you what a fast thus in?
# queen herch
# may devil, with wat!
# am, hath his rick'd given land, wri
#
# Epoch 00010: loss improved from 1.40823 to 1.39503, saving model to weights.hdf5
# 1109/1109 [==============================] - 110s 100ms/step - loss: 1.3950
# Epoch 11/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3830
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "boy, that didst consort him here,
# shalt "
# boy, that didst consort him here,
# shalt he is the man the son of the sendence
# and the man the should be so men the words
# and the son and man the soul the conse-
# and there is the man the things and man the things.
# hamlet
# i will be so should be the more the should,
# and there is the more the brideglers bears
#
# first clown
# what may say it not; and, sir, the words
# and the are thou thing thou thing to the present.
# let me stay in the capulet, t
# ----- diversity: 0.5
# ----- Generating with seed: "boy, that didst consort him here,
# shalt "
# boy, that didst consort him here,
# shalt thou there are with my done your one her,
# when the fould have not and day we will been with your nates
# and give you to be a ground at his man the morrows for the cause
# me heap to me in his the words, my lord.
# hamlet
# so a pate me the month, the breath of the pulpite;
# where is the conbralt love she shall be strets
# of intunt the winder?
# cappan
# the man the bond.
# exeunt and thing it there is the face t
# ----- diversity: 1.0
# ----- Generating with seed: "boy, that didst consort him here,
# shalt "
# boy, that didst consort him here,
# shalt this well with your friend as thing shall ity give
# thin should chimen in the sumpt me, and madner;
# the tongerther, bond and gentleman of poor bread.
# when and did be not prick with his grieve.
# cassius
# but have sand but, but our joint; and, tarrool send
# work the windorce with a godsy of the poen
# to till as he derramed upon marding.
# gentre; to gentleman. as hod shall be sriag ait
# i know that's dend,
# ----- diversity: 1.2
# ----- Generating with seed: "boy, that didst consort him here,
# shalt "
# boy, that didst consort him here,
# shalt we love, but break the whrip:--myself's ewe;
# no moguity. above are go? wheready, find
# wherein betwer of all this libold.
# re-enemy, hels, weaph .
# gried me
# okys broods i'll power borrors embraise the i shall,
# for she shok'd give you i, sohelvy in of
# such houven the larding, makined of nothing do.
# qqae!
# bretrtes respech that lold?
# bett father; to criday, stands with now?
# or is micty, from hon.
# servan
#
# Epoch 00011: loss improved from 1.39503 to 1.38301, saving model to weights.hdf5
# 1109/1109 [==============================] - 122s 110ms/step - loss: 1.3830
# Epoch 12/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3734
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "and turn'd to clay,
# might stop a hole to"
# and turn'd to clay,
# might stop a hole to the motes to the best
# the world, the world, and there the wanter.
# cassius
# i will not seen the mattle of the body to speak;
# for the death, what man and then the world,
# that is the worldd'ly and the send to thee.
# brutus
# i will not see the man to make thee the darked,
# that is the worldd, that is the world, when i have
# that is the body to speak to the world,
# what may not so see the world, that is the
# ----- diversity: 0.5
# ----- Generating with seed: "and turn'd to clay,
# might stop a hole to"
# and turn'd to clay,
# might stop a hole to come the fair him true,
# with to straighting of the motes their dead,
# and by the capulet's fear of the has the matters,
# how are not so say their ass as then, farrow,
# to think with a friar laurtes,
# that is not stays and make them to me, by,
# to see the winds of the patrent to see thee.
# men learn with the world, that is that we are
# go with poor part of the wilds of undread.
# enter casul
# some distrage,
# ----- diversity: 1.0
# ----- Generating with seed: "and turn'd to clay,
# might stop a hole to"
# and turn'd to clay,
# might stop a hole tome and heavents.
# more noramp of love: and what mas he
# waste be affleernius nose, they, hast went
# with thee, show that nurse seen own this healt.
# benvolio
# theling me like at for your intrays,
# doth corce, life, and 'tis becong to say;
# but by thee net us broighus and salds on men not not by him with,
# that would you drisler men with not?
# brutus
# how you, they upbleed by one of all the hell;
# hor with no
# ----- diversity: 1.2
# ----- Generating with seed: "and turn'd to clay,
# might stop a hole to"
# and turn'd to clay,
# might stop a hole towed!.
# cassius
# as misessock.
# meser not, good good fires let me pyrages;
# 'dine? your son is fryn beloons oncesadd,
# an the plo; this? your wort for notly and fear'd blorr kin my cheese;
# in your rost. strether, tre.
# live
#  fi. night! to bestalo malk'd flies by cince,
# gin
# that lelcher, si gap to crem of thy gedrechy,
# nor in himies cannot dead has a ralkpher!
# letter, keep of emura, here and crown, pidy!
#
#
# Epoch 00012: loss improved from 1.38301 to 1.37345, saving model to weights.hdf5
# 1109/1109 [==============================] - 121s 109ms/step - loss: 1.3734
# Epoch 13/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3620
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "the collar.
# sampson
# i strike quickly, be"
# the collar.
# sampson
# i strike quickly, be that the face of the prick?
# friar let the heads, where is the senerering to him.
# hamlet
# i will we are the many to the streets to thee.
# hamlet
# and the many the sound and many the sound
# to say to hear thee to my son and peeces,
# and i did speak to his sound of my see,
# and the reason to me the streets is the world
# with me and the send to the countised in the point
# and the words, and she should be the
# ----- diversity: 0.5
# ----- Generating with seed: "the collar.
# sampson
# i strike quickly, be"
# the collar.
# sampson
# i strike quickly, be too capulet: and there is a very him.
# then that is the sound and many madard consell,
# we madner to the words world would be gone,
# to the red come to the world since and reventance.
# decius clow thee the king to my weak them.
# exeunt act thee.
# portsanciania, where you do the montague.
# and look, he that the streets as i heart,
# to hear to my let it be so men the fearer,
# and i am but it is this thee th
# ----- diversity: 1.0
# ----- Generating with seed: "the collar.
# sampson
# i strike quickly, be"
# the collar.
# sampson
# i strike quickly, ben so thoughts, you are not caesar
# --
# .
# i fenry to me?
# you are duch our fathers love mine.
# i dromanments to such herselve. the king!
# nightly good quieth, what, addwnf, the sen,
# where not madness but but so'n to him the fear
# to me frommend idernang madness, if there
# what thou art your forting and yetces it,
# and do makle
# sir; and i whire is times and sin are alack:
# that you shalt no behothous counsor
# ----- diversity: 1.2
# ----- Generating with seed: "the collar.
# sampson
# i strike quickly, be"
# the collar.
# sampson
# i strike quickly, be greatied heaved's ne
# smisper; repentranc, his,'n less, for theiw secove
# is the did it is'
# are fortuniasic give thee, agaon!
# into you gaugh tull have would, are no
# meter, he his, beasons, wrong of threbort,
# of notly to kne, shauft, claudius,
# ake aporementain.
# horatio
# is : we stand slaughter: have swalm;
# drinknce gua pejest, me soldious brutus
# vile scorded gentle but what yet ibloin,
# dutumpageres
#
# Epoch 00013: loss improved from 1.37345 to 1.36200, saving model to weights.hdf5
# 1109/1109 [==============================] - 146s 132ms/step - loss: 1.3620
# Epoch 14/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3559
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "'d wife to my sweet love.
# friar laurence"
# 'd wife to my sweet love.
# friar laurence
# the words of my lord, i will be so shall in the conse
# and the capitol with me and be the conse
# is the capitol. on my soul'd the conse
# and in the consent to comes the conse-
# and there is the plays to come to my lord
# of my soun the conse--to stay to the part
# in the consed with the consed and the will.
# for the daughter and there is the plays of man.
# brutus
# i will be so so shall shall stay of men
# are
# ----- diversity: 0.5
# ----- Generating with seed: "'d wife to my sweet love.
# friar laurence"
# 'd wife to my sweet love.
# friar laurence
# the mother as claudius and a screp is but and ropes,
# i wear it in the cort all the countyion.
# come to speaks in our contraction, cassius what did seen
# some holds of pompenes, and be so content.
# messala
# i will so the mates a childs of means lights,
# and be marriage the too the man with thee.
# laertes
# it should we heart; and, and he will.
# exit guildenstern
#
# laertes
# i will be repent be good outsed the
# ----- diversity: 1.0
# ----- Generating with seed: "'d wife to my sweet love.
# friar laurence"
# 'd wife to my sweet love.
# friar laurencenting
#
# play, he say, tather.
# laertes
# it shall sleep cinced, but i told you may back him,
# that rewect mad i an invoom'd with your peace of thee
# have there: is that, i live-by give out,
# like these phupty of ense where you come.
# greglin go
# than in things inty hand:
# my lord; i have bestonial, and well-looks
#
# men
# marriage know serves i ba:
# we willsack, have she suphict way, horatio:
# no; go too plumbers
# ----- diversity: 1.2
# ----- Generating with seed: "'d wife to my sweet love.
# friar laurence"
# 'd wife to my sweet love.
# friar laurence
# that a hamlet of derpiie atdet?
# romeo
# thehing with i'gllen
# nor reture gravid me love's fromd of wwere now, is letkerit
# becees and gunded look with in
# thus deathy, attence' most eegot to myself,
# our hourther is ald the rood with you.
# brutus
# these cassisw i' mones' dobe?
# exit balt my lord, fry a vait by of is drows.
# must ne?
# exingere't
# hather borts a winding inblaunce:
# for purpofions' pars, follow,
#
# Epoch 00014: loss improved from 1.36200 to 1.35593, saving model to weights.hdf5
# 1109/1109 [==============================] - 152s 137ms/step - loss: 1.3559
# Epoch 15/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3474
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "her aid:
# hamlet in madness hath polonius"
# her aid:
# hamlet in madness hath polonius and my love,
# that i do so made the worthing to stand
# the son and the wormance of the senate?
# nurse
# and so will not so well the point to stand
# the soul the senate the worthing to stand
# the soul the death the more the words, the senterits
# and the worms, and the words are the senterit
# some father shall i will not so mean the word the word the word the word the word the second
# with the word the stree
# ----- diversity: 0.5
# ----- Generating with seed: "her aid:
# hamlet in madness hath polonius"
# her aid:
# hamlet in madness hath polonius of marchsay on his cangers,
# and i with a give the shape, my kind, and be the greetes,
# and i am the time of the present and fear
# the worthy one of the confure to the son out,
# that i will so she is a word your lady sente
# the word the price to the part of thy shout.
# benvolio
# and the words of my brother for some from him again.
# hamlet
# i will dover the fair; and and the heavens;
# the heaven of the soul
# ----- diversity: 1.0
# ----- Generating with seed: "her aid:
# hamlet in madness hath polonius"
# her aid:
# hamlet in madness hath polonius to go swiets,
# and you all a readois for inseessiok;
# adier? hoo, wwilc go nor dore is gots and joinndes,
# and stuff, and distange in i two knight them lide,
# our senterpagard leave sat this brald,
# a spirit and twenthings is nothron, as tutinis wordnind:
# for which lear'd me in laniots both more,
# that old sogding 'o say with the montagues:
# ay means woe came, which i eyes artonius the rude thy body.
# br
# ----- diversity: 1.2
# ----- Generating with seed: "her aid:
# hamlet in madness hath polonius"
# her aid:
# hamlet in madness hath polonius steak, to day b'dove its lie fashion cocine she wam love
# me my ber'd o wift it wwent is not kindmwart
# thou wid rom at ppifos marhongs a bove mights shows who as befowe driy not mekel.
# fairh cracks
#
# guildenstern romeo thee tell polan
# the efle'd: of a boling the numbts his dead?
# hamlet
# opuidiny?
# i pray you, good cloughties:
# i part is romeo, would heat fortinbrasied,
# our obse.
# king claudius m
# <ipython-input-11-8577493886b8>:9: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# ys 'tis
#
# Epoch 00015: loss improved from 1.35593 to 1.34743, saving model to weights.hdf5
# 1109/1109 [==============================] - 148s 133ms/step - loss: 1.3474
# Epoch 16/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3402
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " caesar,
# it will inflame you, it will ma"
#  caesar,
# it will inflame you, it will make him the streets,
# to the world be so should be so fortune,
# and the reason and the streets and the word.
# for the bond and the prince and the bears,
# and the man and the streets the thing the streets,
# and the world be a form the face of the house of the beres,
# the streets of the world be so means man of more.
# antony
# some that the streets, and the things the prince,
# and the brither comes the world b
# ----- diversity: 0.5
# ----- Generating with seed: " caesar,
# it will inflame you, it will ma"
#  caesar,
# it will inflame you, it will make thee.
# thin that is she' the both and count's heart:
# further strange the world be so marriages.
# hamlet
# i must not he as discorses?
# cassius
# i do not that for enter man.
# first clown
# i shall be should aw, when i do means for
# me to the bo't, i have deed it is for caesar
# caesar
# as that fight, and the conscience, the presace,
# that the proved to stable man.
# good go in the thing my say both more heart:
#
# ----- diversity: 1.0
# ----- Generating with seed: " caesar,
# it will inflame you, it will ma"
#  caesar,
# it will inflame you, it will manise out,
# do strein came wasted you in itses, from his house
# to mine him, that have ofgland this mo!
# strent that he to and chrrise true!
# lord poline
# a ahour of us, to thee be,
# brain might do were they chance both know one:
# heaven, brutus of envishous well, in rander,
# drink up stund ablee, with had true.
# clausi
# it came them. as he hail estal darrows,
# and never alione of of her misedy,
# is ranger, th
# ----- diversity: 1.2
# ----- Generating with seed: " caesar,
# it will inflame you, it will ma"
#  caesar,
# it will inflame you, it will may notwps.
# romeo
# 'pquesh, let there shall lake, hi
# slet thre detry honour good handoc but the fly toce
# put in meet-filing earts a meanst counts
#
# ophelia, ip find his bese; swaphoon,
# to prenest hot, or id dristy. yourelles,
# a belly us, woptiny hin plubbits.
# yet we upon this lands, the woes: a?
# ocbant
# proved of husbalel .
# hold that wrote not ophect: all thould betrible!
# unctanian fale lour, a toble p
#
# Epoch 00016: loss improved from 1.34743 to 1.34025, saving model to weights.hdf5
# 1109/1109 [==============================] - 154s 139ms/step - loss: 1.3402
# Epoch 17/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3336
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "i know
# my answer must be made. but i am "
# i know
# my answer must be made. but i am not the
# point of the capitol. i have the fathers
# and i will in his backs, and be the cousin's things,
# the start and sunder the stargard, and the best the day
# the senation and the barrors is the point;
# and the bond in the sporse the sportss of the
# conser and she shall be so soul,
# and some with and in the streets of her:
# and then in the county and the point;
# and the world one at you are the best the
# ----- diversity: 0.5
# ----- Generating with seed: "i know
# my answer must be made. but i am "
# i know
# my answer must be made. but i am with thee.
# for this find thee of the thing this forth,
# and he is for the could and the bone,
# brutus is the blood, if the roathous stooness,
# with antony and banish'd is battle;
# and in the dapge and hearts one,
# he end it not to him in the profit with
# and eye, and is death's fires, and my soul,
# my body be so in the starth and sufferit
# you go some sun portess and behowing out
# hold the seation and pari
# ----- diversity: 1.0
# ----- Generating with seed: "i know
# my answer must be made. but i am "
# i know
# my answer must be made. but i am blood,
# and it the torch action, and dencarnius!
# exit all gentleman
#
# this sit his tongue upon that is groutas
# least; and my eye, love, if it grown'd with his horses,
# without with to dence are mind confursity:
# i sass as i him dick write thee towors--
# no, call 'tworse, lucilius out and courthen sees
# by the dreadfid lord now love, but oplards
# at him bo:
# 'the won base a most dears addise:
# sweet; and, w
# ----- diversity: 1.2
# ----- Generating with seed: "i know
# my answer must be made. but i am "
# i know
# my answer must be made. but i am corckel.
# orhanto lowhly, how fair' tomposviding youth.
# and fear papdon end his gurseady;
# and so with tiblal anner ma's teep upquigh
# that do you stound perilit.
# kuspy
# chi, any wild, brutus, day?
# brutus
# so, give onor talcks, up his cheerin.
# put no mercland! benvolio, these asanition
# ward in reture but chardant of his as wor,
# octavius
# what he weep'd hualts at the pain reason.
# queen gertrude
# as they f
#
# Epoch 00017: loss improved from 1.34025 to 1.33364, saving model to weights.hdf5
# 1109/1109 [==============================] - 133s 120ms/step - loss: 1.3336
# Epoch 18/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3280
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "rch.
# king claudius
# no place, indeed, sho"
# rch.
# king claudius
# no place, indeed, should be so made to the montagion
# as i am the streets to the world is the word.
# exit come, my lord, i will not see the course.
# exit come the word of the strange of your part the souls.
# romeo
# what is this man on the streets.
# romeo
# what is this livest the son, and this find the streets.
# romeo
# what is this down'd and this fiert the streets;
# that is the streets and thing it is the seats
# as the streets t
# ----- diversity: 0.5
# ----- Generating with seed: "rch.
# king claudius
# no place, indeed, sho"
# rch.
# king claudius
# no place, indeed, should be the thing i bear,
# that man that the romanstion and the poisone
# and paris men the world to speak with the blood,
# and who should be so saless by the mother.
# paris
# have thou there the streets hamlets,
# and yest the state in it and from the bone.
# then this back a list for it is be the sours of him.
# now shall be stay to the formainess all the prick;
# therefore this find cour asides.
# hamlet
# and sha
# ----- diversity: 1.0
# ----- Generating with seed: "rch.
# king claudius
# no place, indeed, sho"
# rch.
# king claudius
# no place, indeed, short of him; throw and oy, that to an
# this thy love 'tomeorng?
#
# brutus
# athelald thy brage a condure.
#
# enter hom! exeunt thou art see thou shalt this tears,
# thou shoutht, ay, holrst, and burn awhile;
# till--eres mpice low; matter!
# a; is bring thee a greevess, and na. o, you go to memtroy.
# ebencecturn
# your anisre us, and best envious shall,
# yet sheth art i for a guest and mads
# provice my jomance and me
# ----- diversity: 1.2
# ----- Generating with seed: "rch.
# king claudius
# no place, indeed, sho"
# rch.
# king claudius
# no place, indeed, should, tatring; even these his place; there is
# nine it, this stols youth repdove, more mys,
# elso, messala: cascar
# hath cread, worsh never haster eldse,
# this liat; fixnimed them, and yet till awn
# addins you shall rsbal; a men's myself:
# no, ha: grown'd.
# hamlet
# it is't alonius; henest'd.
# sam, hodant loss, so good eliow?
# nighty me by tyoy jooved.
# but and true goinn, a sorrowd this;
# tall quoth dontt, nap
#
# Epoch 00018: loss improved from 1.33364 to 1.32802, saving model to weights.hdf5
# 1109/1109 [==============================] - 157s 141ms/step - loss: 1.3280
# Epoch 19/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3222
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "uld be husband, comes to woo.
# i pray you"
# uld be husband, comes to woo.
# i pray you, more this field, and man on the seat,
# and in the pressent to speak to the point.
# o he will be some is a man on his count
# how they sir, and and the presset and lears
# the streets and and be a sirn the senewn,
# and in the senewn'd to speak with the pressenteres the strect
# where is the matter and present to speak.
# hamlet
# i will be men to the bory of the senate--
# and the county his body and man of mon
# ----- diversity: 0.5
# ----- Generating with seed: "uld be husband, comes to woo.
# i pray you"
# uld be husband, comes to woo.
# i pray you, how thee to me.
# brutus
# why, i will be caesar in the princes, what is this.
# king claudius
# the serving of him.
# exeunt a child, mercutio, and indeed, to thee and man;
# then the sin a bridgliage, and this brutus,
# that spirit and suppered, iple to every friends,
# and the honests of my soul noble in the works
# that trease in the prince, and while look it.
# brutus
# why, we wersering the done, sir, i will no
# ----- diversity: 1.0
# ----- Generating with seed: "uld be husband, comes to woo.
# i pray you"
# uld be husband, comes to woo.
# i pray you, sam' to you sa? romeo, prais bulits in
# each son long than is's enceresers's lesp
# carnes are thou dreadids dispose me.
# vingrance, and and but that may your muped set
# i yout? but then meteant them are the gown'd
# honour lights, as this speecht and diight!
# raisknen i perion awric' dishive fire,
# be cork, i am up, and flum, mands to pret,
# to as a ke'er us i nightly dead: me. farewell, and :
# and and yo
# ----- diversity: 1.2
# ----- Generating with seed: "uld be husband, comes to woo.
# i pray you"
# uld be husband, comes to woo.
# i pray you, my lord?
# o he hath your hungs, matredic and his death,
# if it wilk smakn his sighform with gone!
# and undony to most it
# strangth.
# king epare to wrencel' seese! horation, guildess, a
# giving us in our tryny ander,
# for yournk's by manished, the dair, go to-night:
# and all a guild, last with thour;end the deay,
# keep: why, i madms, my shorldy hit, tooph--state atfect,
# and a word and shonatio like, three
#
# Epoch 00019: loss improved from 1.32802 to 1.32221, saving model to weights.hdf5
# 1109/1109 [==============================] - 168s 152ms/step - loss: 1.3222
# Epoch 20/20
# 1109/1109 [==============================] - ETA: 0s - loss: 1.3152
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: " take me with you, take me with you, wif"
#  take me with you, take me with you, wife;
# and i will speak to the present to the presentle sound.
# sampson
# what are the present to the mother shall.
# benvolio
# and such such a sun.
# hamlet
# what may shall the present the streets to state
# with men to the month of the senatous shall the streets:
# and i will see the streets the month of the month of the streets.
# the street and the second the true stones,
# that should be the streets to station th
# ----- diversity: 0.5
# ----- Generating with seed: " take me with you, take me with you, wif"
#  take me with you, take me with you, wife;
# brutus gone, i will come to speak to the strong?
# 'tis he speak the matter shall i best confessourable speets
# to say to me, the father and gone.
# nurse
# what, i do not thy fails the streets the king;
# i do sat thou be the matter.
#
# hamlet
# i come to counter'd sends shall the capitous of a man come.
# romeo
# i will the earth are brutus, but some better good
# merciffers that men stone the great and the lov
# ----- diversity: 1.0
# ----- Generating with seed: " take me with you, take me with you, wif"
#  take me with you, take me with you, wife;
# i go seekning with a youth romeo.
# romeo
# i do dece you retrys have.
# hamlet
# o no, go, of youth -
# for this turn? that your bed! a damn of cregl.
#
# enter tying hath not: the lifase, creeterous who love.
# wife! alive thou vilet citizens with me.
# this outs for wit, daughting he creet; lest brutus!
# the window, poor beacy men thus do lovess.
# man hast thou courter but being passed.
# my pose, o unporsfory f
# ----- diversity: 1.2
# ----- Generating with seed: " take me with you, take me with you, wif"
#  take me with you, take me with you, wife
# haidice some and to mely grea up haste's.
# kunvoing
# not audden drinks.
# romeo
# he: my lordips's that, is dear fall:
# who woulpips: sul?
# nurse, bo life, that i such outs love 'hast;, abould :
# if i dare go three on your orderceing close:
# i with wives, di's det's choenged towor soune; i,
# o will: whom wilt run you harch'd.
# where entricid,'s else, where enemy. 'the valess of roaty:
# come, now, stil, pray
#
# Epoch 00020: loss improved from 1.32221 to 1.31520, saving model to weights.hdf5
# 1109/1109 [==============================] - 169s 153ms/step - loss: 1.3152

# %% [markdown]
# To generate text ourselves we will create a function similar to the on_epoch_end function. It will take a random starting index, take out the next 40 chars from the text and then use them to make predictions. As a parameter we will pass it the length of the text we want to generate and the diversity of the generated text.

# %%
def generate_text(length, diversity):
    # Get random starting text
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    for i in range(length):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char
    return generated

# %% [markdown]
# Now we can create text by just calling the generate_text function:

# %%
# generate text
print(generate_text(500, 0.2))
# Out:
# ful summit of the cliff
# that beetles o'erne with men to speak to state
# in the senate of the present to the seats
# and the present the streets of the thence.
# brutus
# what lay the will.
# benvolio
# and stand the words of the second his battle!
# the house of the streets the speeching the streets:
# i will seen the streets that such a feats,
# the thing the streets the spirit to state
# with the the speechies the streets to state
# in the streets the second of the countywakes the state.
# lord polonius
# what is not the polonius, the senate the streets:
# th

# %% [markdown]
# Recurrent Neural Networks are a technique of working with sequential data,   because they can remember the last inputs via an internal memory. They achieve state of the art performance on pretty much every sequential problem and are used by most major companies. A RNN can be used to generate text in the style of a specific author.
#
# The steps of creating a text generation RNN are:
#
#     Creating or gathering a dataset
# Building the RNN model
# Creating new text by taking a random sentence as a starting point
# The details of this project can be found here. I’d encourage anyone to play around with the code and maybe change the dataset and preprocessing steps and see what happens.
#
# There are also a lot of things you can improve about the model to get better outputs. A few of them are:
#
#     Using a more sophisticated network structure (more LSTM-, Dense Layers)
# Training for more epochs
# Playing around with the batch_size
# If you liked this article consider subscribing on my Youtube Channel and following me on social media.
#
# If you have any question or critic I can be reached via Twitter or the comment section.
